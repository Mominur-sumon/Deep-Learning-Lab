# %% [markdown]
# Compare performance of 10 CNNs pre-trained on ImageNet dataset using images of 20 classes of CIFAR-100 dataset.
# Students need to submit individual hand-written report via CR on 25.5.2025 (Sunday) before CSE4261 class.
# Code + digital report should be submitted to the Assignment box by scheduled time.
# Students may compare models based on accuracy, hardware requirements, size of the model, inference time, architecture etc.

# %%
from tensorflow.keras.datasets import cifar100
import matplotlib.pyplot as plt
import numpy as np
import cv2

from tensorflow.keras.applications.vgg16 import preprocess_input
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model

# %%
(trainX, trainY), (testX, testY) = cifar100.load_data(label_mode='fine')
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)

for i in range(16):
  plt.subplot(4, 4, i+1)
  plt.imshow(trainX[i])
  plt.title(trainY[i])
  plt.tight_layout()
  plt.axis('off')
plt.show()
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ## Select first 20 class from 100 class

# %%
# Flatten labels
trainY = trainY.flatten()
testY = testY.flatten()

# Select first 20 odd indices
selected_indices = list(range(20))

# Create boolean masks
train_mask = np.isin(trainY, selected_indices)
test_mask = np.isin(testY, selected_indices)

# Filter data
trainX= trainX[train_mask]
trainY= trainY[train_mask]
testX= testX[test_mask]
testY= testY[test_mask]

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)

for i in range(16):
  plt.subplot(4, 4, i+1)
  plt.imshow(trainX[i])
  plt.title(trainY[i])
  plt.tight_layout()
  plt.axis('off')
plt.show()
# Out:
# (10000, 32, 32, 3)
# (10000,)
# (2000, 32, 32, 3)
# (2000,)

# %%
def resize_images(images, size=(224, 224)):
    resized_images = []
    for img in images:
        resized = cv2.resize(img, size, interpolation=cv2.INTER_LINEAR)
        resized_images.append(resized)
    return np.array(resized_images)

# %%
trainX_resized = resize_images(trainX)
testX_resized = resize_images(testX)

# Preprocess input for VGG16
trainX_preprocessed = preprocess_input(trainX_resized)
testX_preprocessed = preprocess_input(testX_resized)


print("Resized and preprocessed images for the model.")

print(trainX_preprocessed.shape)
print(testX_preprocessed.shape)
# Out:
# Resized and preprocessed images for the model.
# (10000, 224, 224, 3)
# (2000, 224, 224, 3)

# %% [markdown]
# ## Load VGG16 model

# %%
from tensorflow.keras.applications import VGG16


# Load VGG16 base model
vgg16_base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

vgg16_base_model.trainable = False

inputs = vgg16_base_model.inputs
x = vgg16_base_model.output
x = Flatten()(x)
x = Dense(64, activation = 'relu')(x)
x = Dense(32, activation = 'relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='VGG16')
model.summary(show_trainable=True)
# Out:
# Model: "VGG16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_11 (InputLayer) │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv1 (Conv2D)       │ (None, 224, 224, 64)  │      1,792 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv2 (Conv2D)       │ (None, 224, 224, 64)  │     36,928 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_pool (MaxPooling2D)  │ (None, 112, 112, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv1 (Conv2D)       │ (None, 112, 112, 128) │     73,856 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv2 (Conv2D)       │ (None, 112, 112, 128) │    147,584 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_pool (MaxPooling2D)  │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv1 (Conv2D)       │ (None, 56, 56, 256)   │    295,168 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv2 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv3 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_pool (MaxPooling2D)  │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv1 (Conv2D)       │ (None, 28, 28, 512)   │  1,180,160 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv2 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv3 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_pool (MaxPooling2D)  │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv1 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv2 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv3 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_pool (MaxPooling2D)  │ (None, 7, 7, 512)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten_11 (Flatten)        │ (None, 25088)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_33 (Dense)            │ (None, 64)            │  1,605,696 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_34 (Dense)            │ (None, 32)            │      2,080 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_35 (Dense)            │ (None, 20)            │        660 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 16,323,124 (62.27 MB)
#  Trainable params: 1,608,436 (6.14 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# ### Compile and evaluate the VGG16 model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
vgg16_history= model.evaluate(testX_preprocessed, testY)
# Out:
# c:\Users\Md Mominur Rahman\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor_2865']. Received: the structure of inputs=*
#   warnings.warn(
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - accuracy: 0.0602 - loss: 7.5847

# %%
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')

test_accuracy = vgg16_history[1] * 100

# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']

plt.figure(figsize=(8, 4))
bars = plt.bar(labels, values, color=colors)

plt.yscale('log')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)

plt.title('VGG16 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()

plt.show()
# Out:
# Total parameters: 7584136
# Trainable parameters: 3314420
# Non-trainable parameters: 4269716

# %% [markdown]
# ## Load VGG19 (Pretrained on ImageNet)

# %%
from tensorflow.keras.applications import VGG19

vgg19_base = VGG19(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
vgg19_base.trainable = False
inputs=vgg19_base.input
# Add classification layers
x = Flatten()(vgg19_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)

model = Model(inputs, outputs, name='VGG19')
model.summary(show_trainable=True)
# Out:
# Model: "VGG19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_12 (InputLayer) │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv1 (Conv2D)       │ (None, 224, 224, 64)  │      1,792 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_conv2 (Conv2D)       │ (None, 224, 224, 64)  │     36,928 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block1_pool (MaxPooling2D)  │ (None, 112, 112, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv1 (Conv2D)       │ (None, 112, 112, 128) │     73,856 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_conv2 (Conv2D)       │ (None, 112, 112, 128) │    147,584 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block2_pool (MaxPooling2D)  │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv1 (Conv2D)       │ (None, 56, 56, 256)   │    295,168 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv2 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv3 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_conv4 (Conv2D)       │ (None, 56, 56, 256)   │    590,080 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block3_pool (MaxPooling2D)  │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv1 (Conv2D)       │ (None, 28, 28, 512)   │  1,180,160 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv2 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv3 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_conv4 (Conv2D)       │ (None, 28, 28, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block4_pool (MaxPooling2D)  │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv1 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv2 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv3 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_conv4 (Conv2D)       │ (None, 14, 14, 512)   │  2,359,808 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ block5_pool (MaxPooling2D)  │ (None, 7, 7, 512)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten_12 (Flatten)        │ (None, 25088)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_36 (Dense)            │ (None, 64)            │  1,605,696 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_37 (Dense)            │ (None, 32)            │      2,080 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_38 (Dense)            │ (None, 20)            │        660 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 21,632,820 (82.52 MB)
#  Trainable params: 1,608,436 (6.14 MB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %% [markdown]
# ### VGG19 with 20 class output layer model summary

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
vgg19_history= model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 684s 11s/step - accuracy: 0.0490 - loss: 9.6481

# %%
test_accuracy = vgg19_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')

# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('VGG19 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 21632820
# Trainable parameters: 1608436
# Non-trainable parameters: 20024384

# %% [markdown]
# ## Load ResNet50 pretrained Model

# %%
from tensorflow.keras.applications import ResNet50

resnet50_base = ResNet50(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
resnet50_base.trainable = False
inputs=resnet50_base.input
# Add classification layers
x = Flatten()(resnet50_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)

model = Model(inputs, outputs, name='ResNet50')
model.summary(show_trainable=True)
# Out:
# Model: "ResNet50"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_13    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_pad         │ (None, 230,     │         0 │ input_layer_1… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,472 │ conv1_pad[0][… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_bn          │ (None, 112,     │       256 │ conv1_conv[0]… │   N   │
# │ (BatchNormalizat… │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_relu        │ (None, 112,     │         0 │ conv1_bn[0][0] │   -   │
# │ (Activation)      │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pad         │ (None, 114,     │         0 │ conv1_relu[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1_pool        │ (None, 56, 56,  │         0 │ pool1_pad[0][… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     4,160 │ pool1_pool[0]… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_bn │ (None, 56, 56,  │       256 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_c… │ (None, 56, 56,  │    16,640 │ pool1_pool[0]… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_bn │ (None, 56, 56,  │     1,024 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_add  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_out  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    16,448 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_bn │ (None, 56, 56,  │       256 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_add  │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_out  │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,448 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 56, 56,  │    36,928 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_bn │ (None, 56, 56,  │       256 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_3_c… │ (None, 56, 56,  │    16,640 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_3_bn │ (None, 56, 56,  │     1,024 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_add  │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Add)             │ 256)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_out  │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    32,896 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_c… │ (None, 28, 28,  │   131,584 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_bn │ (None, 28, 28,  │     2,048 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_add  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_out  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_add  │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_out  │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_add  │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_out  │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    65,664 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 28, 28,  │   147,584 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_3_c… │ (None, 28, 28,  │    66,048 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_3_bn │ (None, 28, 28,  │     2,048 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_add  │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Add)             │ 512)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_out  │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │   131,328 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_c… │ (None, 14, 14,  │   525,312 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_bn │ (None, 14, 14,  │     4,096 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_add  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_out  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_add  │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_out  │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_add  │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_out  │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_add  │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_out  │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_add  │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_out  │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │   262,400 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 14, 14,  │   590,080 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_bn │ (None, 14, 14,  │     1,024 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_3_c… │ (None, 14, 14,  │   263,168 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_3_bn │ (None, 14, 14,  │     4,096 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_add  │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Add)             │ 1024)           │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_out  │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_c… │ (None, 7, 7,    │   524,800 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_1_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_2_r… │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_0_c… │ (None, 7, 7,    │ 2,099,200 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_0_bn │ (None, 7, 7,    │     8,192 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block1_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_add  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block1_out  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_c… │ (None, 7, 7,    │ 1,049,088 │ conv5_block1_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_1_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_2_r… │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block2_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_add  │ (None, 7, 7,    │         0 │ conv5_block1_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block2_out  │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_c… │ (None, 7, 7,    │ 1,049,088 │ conv5_block2_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_1_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_c… │ (None, 7, 7,    │ 2,359,808 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_bn │ (None, 7, 7,    │     2,048 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_2_r… │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_3_c… │ (None, 7, 7,    │ 1,050,624 │ conv5_block3_… │   N   │
# │ (Conv2D)          │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_3_bn │ (None, 7, 7,    │     8,192 │ conv5_block3_… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_add  │ (None, 7, 7,    │         0 │ conv5_block2_… │   -   │
# │ (Add)             │ 2048)           │           │ conv5_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block3_out  │ (None, 7, 7,    │         0 │ conv5_block3_… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_13        │ (None, 100352)  │         0 │ conv5_block3_… │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_39 (Dense)  │ (None, 64)      │ 6,422,592 │ flatten_13[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_40 (Dense)  │ (None, 32)      │     2,080 │ dense_39[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_41 (Dense)  │ (None, 20)      │       660 │ dense_40[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 30,013,044 (114.49 MB)
#  Trainable params: 6,425,332 (24.51 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# ### Compile and evaluate the resnet50

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
resnet50_history= model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 207s 3s/step - accuracy: 0.0558 - loss: 4.1381

# %%
test_accuracy = resnet50_history[1] * 100
print(f'Test accuracy: {test_accuracy:.2f}%')
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('ResNet50 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Test accuracy: 5.05%
# Total parameters: 30013044
# Trainable parameters: 6425332
# Non-trainable parameters: 23587712

# %% [markdown]
# ## Load Mobilenet pretrained Model

# %%
from tensorflow.keras.applications import MobileNet
mobilenet_base = MobileNet(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
mobilenet_base.trainable = False
inputs=mobilenet_base.input
# Add classification layers
x = Flatten()(mobilenet_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='MobileNet')
model.summary(show_trainable=True)
# Out:
# Model: "MobileNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)                ┃ Output Shape          ┃    Param # ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_14 (InputLayer) │ (None, 224, 224, 3)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1 (Conv2D)              │ (None, 112, 112, 32)  │        864 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1_bn                    │ (None, 112, 112, 32)  │        128 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv1_relu (ReLU)           │ (None, 112, 112, 32)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_1 (DepthwiseConv2D) │ (None, 112, 112, 32)  │        288 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_1_bn                │ (None, 112, 112, 32)  │        128 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_1_relu (ReLU)       │ (None, 112, 112, 32)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_1 (Conv2D)          │ (None, 112, 112, 64)  │      2,048 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_1_bn                │ (None, 112, 112, 64)  │        256 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_1_relu (ReLU)       │ (None, 112, 112, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pad_2 (ZeroPadding2D)  │ (None, 113, 113, 64)  │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_2 (DepthwiseConv2D) │ (None, 56, 56, 64)    │        576 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_2_bn                │ (None, 56, 56, 64)    │        256 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_2_relu (ReLU)       │ (None, 56, 56, 64)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_2 (Conv2D)          │ (None, 56, 56, 128)   │      8,192 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_2_bn                │ (None, 56, 56, 128)   │        512 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_2_relu (ReLU)       │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_3 (DepthwiseConv2D) │ (None, 56, 56, 128)   │      1,152 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_3_bn                │ (None, 56, 56, 128)   │        512 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_3_relu (ReLU)       │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_3 (Conv2D)          │ (None, 56, 56, 128)   │     16,384 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_3_bn                │ (None, 56, 56, 128)   │        512 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_3_relu (ReLU)       │ (None, 56, 56, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pad_4 (ZeroPadding2D)  │ (None, 57, 57, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_4 (DepthwiseConv2D) │ (None, 28, 28, 128)   │      1,152 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_4_bn                │ (None, 28, 28, 128)   │        512 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_4_relu (ReLU)       │ (None, 28, 28, 128)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_4 (Conv2D)          │ (None, 28, 28, 256)   │     32,768 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_4_bn                │ (None, 28, 28, 256)   │      1,024 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_4_relu (ReLU)       │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_5 (DepthwiseConv2D) │ (None, 28, 28, 256)   │      2,304 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_5_bn                │ (None, 28, 28, 256)   │      1,024 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_5_relu (ReLU)       │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_5 (Conv2D)          │ (None, 28, 28, 256)   │     65,536 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_5_bn                │ (None, 28, 28, 256)   │      1,024 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_5_relu (ReLU)       │ (None, 28, 28, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pad_6 (ZeroPadding2D)  │ (None, 29, 29, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_6 (DepthwiseConv2D) │ (None, 14, 14, 256)   │      2,304 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_6_bn                │ (None, 14, 14, 256)   │      1,024 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_6_relu (ReLU)       │ (None, 14, 14, 256)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_6 (Conv2D)          │ (None, 14, 14, 512)   │    131,072 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_6_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_6_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_7 (DepthwiseConv2D) │ (None, 14, 14, 512)   │      4,608 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_7_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_7_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_7 (Conv2D)          │ (None, 14, 14, 512)   │    262,144 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_7_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_7_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_8 (DepthwiseConv2D) │ (None, 14, 14, 512)   │      4,608 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_8_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_8_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_8 (Conv2D)          │ (None, 14, 14, 512)   │    262,144 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_8_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_8_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_9 (DepthwiseConv2D) │ (None, 14, 14, 512)   │      4,608 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_9_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_9_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_9 (Conv2D)          │ (None, 14, 14, 512)   │    262,144 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_9_bn                │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_9_relu (ReLU)       │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_10                  │ (None, 14, 14, 512)   │      4,608 │   N   │
# │ (DepthwiseConv2D)           │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_10_bn               │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_10_relu (ReLU)      │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_10 (Conv2D)         │ (None, 14, 14, 512)   │    262,144 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_10_bn               │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_10_relu (ReLU)      │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_11                  │ (None, 14, 14, 512)   │      4,608 │   N   │
# │ (DepthwiseConv2D)           │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_11_bn               │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_11_relu (ReLU)      │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_11 (Conv2D)         │ (None, 14, 14, 512)   │    262,144 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_11_bn               │ (None, 14, 14, 512)   │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_11_relu (ReLU)      │ (None, 14, 14, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pad_12 (ZeroPadding2D) │ (None, 15, 15, 512)   │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_12                  │ (None, 7, 7, 512)     │      4,608 │   N   │
# │ (DepthwiseConv2D)           │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_12_bn               │ (None, 7, 7, 512)     │      2,048 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_12_relu (ReLU)      │ (None, 7, 7, 512)     │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_12 (Conv2D)         │ (None, 7, 7, 1024)    │    524,288 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_12_bn               │ (None, 7, 7, 1024)    │      4,096 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_12_relu (ReLU)      │ (None, 7, 7, 1024)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_13                  │ (None, 7, 7, 1024)    │      9,216 │   N   │
# │ (DepthwiseConv2D)           │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_13_bn               │ (None, 7, 7, 1024)    │      4,096 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_dw_13_relu (ReLU)      │ (None, 7, 7, 1024)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_13 (Conv2D)         │ (None, 7, 7, 1024)    │  1,048,576 │   N   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_13_bn               │ (None, 7, 7, 1024)    │      4,096 │   N   │
# │ (BatchNormalization)        │                       │            │       │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ conv_pw_13_relu (ReLU)      │ (None, 7, 7, 1024)    │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ flatten_14 (Flatten)        │ (None, 50176)         │          0 │   -   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_42 (Dense)            │ (None, 64)            │  3,211,328 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_43 (Dense)            │ (None, 32)            │      2,080 │   Y   │
# ├─────────────────────────────┼───────────────────────┼────────────┼───────┤
# │ dense_44 (Dense)            │ (None, 20)            │        660 │   Y   │
# └─────────────────────────────┴───────────────────────┴────────────┴───────┘
#  Total params: 6,442,932 (24.58 MB)
#  Trainable params: 3,214,068 (12.26 MB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mobilenet_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 52s 783ms/step - accuracy: 0.0517 - loss: 3.8385

# %%
test_accuracy = mobilenet_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')

# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('MobileNet Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 6442932
# Trainable parameters: 3214068
# Non-trainable parameters: 3228864

# %% [markdown]
# ## Load MobilenetV2

# %%
from tensorflow.keras.applications import MobileNetV2
mobilenetv2_base = MobileNetV2(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
mobilenetv2_base.trainable = False
inputs=mobilenetv2_base.input
# Add classification layers
x = Flatten()(mobilenetv2_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='MobileNetV2')
model.summary(show_trainable=True)
# Out:
# Model: "MobileNetV2"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_15    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1 (Conv2D)    │ (None, 112,     │       864 │ input_layer_1… │   N   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn_Conv1          │ (None, 112,     │       128 │ Conv1[0][0]    │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv1_relu (ReLU) │ (None, 112,     │         0 │ bn_Conv1[0][0] │   -   │
# │                   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       288 │ Conv1_relu[0]… │   N   │
# │ (DepthwiseConv2D) │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │       128 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_de… │ (None, 112,     │         0 │ expanded_conv… │   -   │
# │ (ReLU)            │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │       512 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ expanded_conv_pr… │ (None, 112,     │        64 │ expanded_conv… │   N   │
# │ (BatchNormalizat… │ 112, 16)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand    │ (None, 112,     │     1,536 │ expanded_conv… │   N   │
# │ (Conv2D)          │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_BN │ (None, 112,     │       384 │ block_1_expan… │   N   │
# │ (BatchNormalizat… │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_expand_r… │ (None, 112,     │         0 │ block_1_expan… │   -   │
# │ (ReLU)            │ 112, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_pad       │ (None, 113,     │         0 │ block_1_expan… │   -   │
# │ (ZeroPadding2D)   │ 113, 96)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwise │ (None, 56, 56,  │       864 │ block_1_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │       384 │ block_1_depth… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_depthwis… │ (None, 56, 56,  │         0 │ block_1_depth… │   -   │
# │ (ReLU)            │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project   │ (None, 56, 56,  │     2,304 │ block_1_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_1_project_… │ (None, 56, 56,  │        96 │ block_1_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand    │ (None, 56, 56,  │     3,456 │ block_1_proje… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_BN │ (None, 56, 56,  │       576 │ block_2_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_expand_r… │ (None, 56, 56,  │         0 │ block_2_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwise │ (None, 56, 56,  │     1,296 │ block_2_expan… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │       576 │ block_2_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_depthwis… │ (None, 56, 56,  │         0 │ block_2_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project   │ (None, 56, 56,  │     3,456 │ block_2_depth… │   N   │
# │ (Conv2D)          │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_project_… │ (None, 56, 56,  │        96 │ block_2_proje… │   N   │
# │ (BatchNormalizat… │ 24)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_2_add (Add) │ (None, 56, 56,  │         0 │ block_1_proje… │   -   │
# │                   │ 24)             │           │ block_2_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand    │ (None, 56, 56,  │     3,456 │ block_2_add[0… │   N   │
# │ (Conv2D)          │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_BN │ (None, 56, 56,  │       576 │ block_3_expan… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_expand_r… │ (None, 56, 56,  │         0 │ block_3_expan… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_pad       │ (None, 57, 57,  │         0 │ block_3_expan… │   -   │
# │ (ZeroPadding2D)   │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwise │ (None, 28, 28,  │     1,296 │ block_3_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │       576 │ block_3_depth… │   N   │
# │ (BatchNormalizat… │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_depthwis… │ (None, 28, 28,  │         0 │ block_3_depth… │   -   │
# │ (ReLU)            │ 144)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project   │ (None, 28, 28,  │     4,608 │ block_3_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_3_project_… │ (None, 28, 28,  │       128 │ block_3_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand    │ (None, 28, 28,  │     6,144 │ block_3_proje… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_BN │ (None, 28, 28,  │       768 │ block_4_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_expand_r… │ (None, 28, 28,  │         0 │ block_4_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwise │ (None, 28, 28,  │     1,728 │ block_4_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │       768 │ block_4_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_depthwis… │ (None, 28, 28,  │         0 │ block_4_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project   │ (None, 28, 28,  │     6,144 │ block_4_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_project_… │ (None, 28, 28,  │       128 │ block_4_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_4_add (Add) │ (None, 28, 28,  │         0 │ block_3_proje… │   -   │
# │                   │ 32)             │           │ block_4_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand    │ (None, 28, 28,  │     6,144 │ block_4_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_BN │ (None, 28, 28,  │       768 │ block_5_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_expand_r… │ (None, 28, 28,  │         0 │ block_5_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwise │ (None, 28, 28,  │     1,728 │ block_5_expan… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │       768 │ block_5_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_depthwis… │ (None, 28, 28,  │         0 │ block_5_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project   │ (None, 28, 28,  │     6,144 │ block_5_depth… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_project_… │ (None, 28, 28,  │       128 │ block_5_proje… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_5_add (Add) │ (None, 28, 28,  │         0 │ block_4_add[0… │   -   │
# │                   │ 32)             │           │ block_5_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand    │ (None, 28, 28,  │     6,144 │ block_5_add[0… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_BN │ (None, 28, 28,  │       768 │ block_6_expan… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_expand_r… │ (None, 28, 28,  │         0 │ block_6_expan… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_pad       │ (None, 29, 29,  │         0 │ block_6_expan… │   -   │
# │ (ZeroPadding2D)   │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwise │ (None, 14, 14,  │     1,728 │ block_6_pad[0… │   N   │
# │ (DepthwiseConv2D) │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │       768 │ block_6_depth… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_depthwis… │ (None, 14, 14,  │         0 │ block_6_depth… │   -   │
# │ (ReLU)            │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project   │ (None, 14, 14,  │    12,288 │ block_6_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_6_project_… │ (None, 14, 14,  │       256 │ block_6_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand    │ (None, 14, 14,  │    24,576 │ block_6_proje… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_BN │ (None, 14, 14,  │     1,536 │ block_7_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_expand_r… │ (None, 14, 14,  │         0 │ block_7_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwise │ (None, 14, 14,  │     3,456 │ block_7_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │     1,536 │ block_7_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_depthwis… │ (None, 14, 14,  │         0 │ block_7_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project   │ (None, 14, 14,  │    24,576 │ block_7_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_project_… │ (None, 14, 14,  │       256 │ block_7_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_7_add (Add) │ (None, 14, 14,  │         0 │ block_6_proje… │   -   │
# │                   │ 64)             │           │ block_7_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand    │ (None, 14, 14,  │    24,576 │ block_7_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_BN │ (None, 14, 14,  │     1,536 │ block_8_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_expand_r… │ (None, 14, 14,  │         0 │ block_8_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwise │ (None, 14, 14,  │     3,456 │ block_8_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │     1,536 │ block_8_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_depthwis… │ (None, 14, 14,  │         0 │ block_8_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project   │ (None, 14, 14,  │    24,576 │ block_8_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_project_… │ (None, 14, 14,  │       256 │ block_8_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_8_add (Add) │ (None, 14, 14,  │         0 │ block_7_add[0… │   -   │
# │                   │ 64)             │           │ block_8_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand    │ (None, 14, 14,  │    24,576 │ block_8_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_BN │ (None, 14, 14,  │     1,536 │ block_9_expan… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_expand_r… │ (None, 14, 14,  │         0 │ block_9_expan… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwise │ (None, 14, 14,  │     3,456 │ block_9_expan… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │     1,536 │ block_9_depth… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_depthwis… │ (None, 14, 14,  │         0 │ block_9_depth… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project   │ (None, 14, 14,  │    24,576 │ block_9_depth… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_project_… │ (None, 14, 14,  │       256 │ block_9_proje… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_9_add (Add) │ (None, 14, 14,  │         0 │ block_8_add[0… │   -   │
# │                   │ 64)             │           │ block_9_proje… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand   │ (None, 14, 14,  │    24,576 │ block_9_add[0… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │     1,536 │ block_10_expa… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_expand_… │ (None, 14, 14,  │         0 │ block_10_expa… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     3,456 │ block_10_expa… │   N   │
# │ (DepthwiseConv2D) │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │     1,536 │ block_10_dept… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_depthwi… │ (None, 14, 14,  │         0 │ block_10_dept… │   -   │
# │ (ReLU)            │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project  │ (None, 14, 14,  │    36,864 │ block_10_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_10_project… │ (None, 14, 14,  │       384 │ block_10_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand   │ (None, 14, 14,  │    55,296 │ block_10_proj… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │     2,304 │ block_11_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_expand_… │ (None, 14, 14,  │         0 │ block_11_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     5,184 │ block_11_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │     2,304 │ block_11_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_depthwi… │ (None, 14, 14,  │         0 │ block_11_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project  │ (None, 14, 14,  │    55,296 │ block_11_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_project… │ (None, 14, 14,  │       384 │ block_11_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_11_add      │ (None, 14, 14,  │         0 │ block_10_proj… │   -   │
# │ (Add)             │ 96)             │           │ block_11_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand   │ (None, 14, 14,  │    55,296 │ block_11_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │     2,304 │ block_12_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_expand_… │ (None, 14, 14,  │         0 │ block_12_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     5,184 │ block_12_expa… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │     2,304 │ block_12_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_depthwi… │ (None, 14, 14,  │         0 │ block_12_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project  │ (None, 14, 14,  │    55,296 │ block_12_dept… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_project… │ (None, 14, 14,  │       384 │ block_12_proj… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_12_add      │ (None, 14, 14,  │         0 │ block_11_add[… │   -   │
# │ (Add)             │ 96)             │           │ block_12_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand   │ (None, 14, 14,  │    55,296 │ block_12_add[… │   N   │
# │ (Conv2D)          │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │     2,304 │ block_13_expa… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_expand_… │ (None, 14, 14,  │         0 │ block_13_expa… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_pad      │ (None, 15, 15,  │         0 │ block_13_expa… │   -   │
# │ (ZeroPadding2D)   │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     5,184 │ block_13_pad[… │   N   │
# │ (DepthwiseConv2D) │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │     2,304 │ block_13_dept… │   N   │
# │ (BatchNormalizat… │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_depthwi… │ (None, 7, 7,    │         0 │ block_13_dept… │   -   │
# │ (ReLU)            │ 576)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project  │ (None, 7, 7,    │    92,160 │ block_13_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_13_project… │ (None, 7, 7,    │       640 │ block_13_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand   │ (None, 7, 7,    │   153,600 │ block_13_proj… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │     3,840 │ block_14_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_expand_… │ (None, 7, 7,    │         0 │ block_14_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     8,640 │ block_14_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │     3,840 │ block_14_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_depthwi… │ (None, 7, 7,    │         0 │ block_14_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project  │ (None, 7, 7,    │   153,600 │ block_14_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_project… │ (None, 7, 7,    │       640 │ block_14_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_14_add      │ (None, 7, 7,    │         0 │ block_13_proj… │   -   │
# │ (Add)             │ 160)            │           │ block_14_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand   │ (None, 7, 7,    │   153,600 │ block_14_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │     3,840 │ block_15_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_expand_… │ (None, 7, 7,    │         0 │ block_15_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     8,640 │ block_15_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │     3,840 │ block_15_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_depthwi… │ (None, 7, 7,    │         0 │ block_15_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project  │ (None, 7, 7,    │   153,600 │ block_15_dept… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_project… │ (None, 7, 7,    │       640 │ block_15_proj… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_15_add      │ (None, 7, 7,    │         0 │ block_14_add[… │   -   │
# │ (Add)             │ 160)            │           │ block_15_proj… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand   │ (None, 7, 7,    │   153,600 │ block_15_add[… │   N   │
# │ (Conv2D)          │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │     3,840 │ block_16_expa… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_expand_… │ (None, 7, 7,    │         0 │ block_16_expa… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     8,640 │ block_16_expa… │   N   │
# │ (DepthwiseConv2D) │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │     3,840 │ block_16_dept… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_depthwi… │ (None, 7, 7,    │         0 │ block_16_dept… │   -   │
# │ (ReLU)            │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project  │ (None, 7, 7,    │   307,200 │ block_16_dept… │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block_16_project… │ (None, 7, 7,    │     1,280 │ block_16_proj… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv_1 (Conv2D)   │ (None, 7, 7,    │   409,600 │ block_16_proj… │   N   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ Conv_1_bn         │ (None, 7, 7,    │     5,120 │ Conv_1[0][0]   │   N   │
# │ (BatchNormalizat… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ out_relu (ReLU)   │ (None, 7, 7,    │         0 │ Conv_1_bn[0][… │   -   │
# │                   │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_15        │ (None, 62720)   │         0 │ out_relu[0][0] │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_45 (Dense)  │ (None, 64)      │ 4,014,144 │ flatten_15[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_46 (Dense)  │ (None, 32)      │     2,080 │ dense_45[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_47 (Dense)  │ (None, 20)      │       660 │ dense_46[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 6,274,868 (23.94 MB)
#  Trainable params: 4,016,884 (15.32 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# ## compile and evaluate MobilenetV2

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
mobilenetv2_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 62s 926ms/step - accuracy: 0.0437 - loss: 3.4808

# %%
test_accuracy = mobilenet_history[1] * 100
print(f'Test accuracy: {test_accuracy:.2f}%')
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('MobileNetV2 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Test accuracy: 4.30%
# Total parameters: 6274868
# Trainable parameters: 4016884
# Non-trainable parameters: 2257984

# %% [markdown]
# ## Load DenseNet121

# %%
from tensorflow.keras.applications import DenseNet121
densenet121_base = DenseNet121(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
densenet121_base.trainable = False
inputs=densenet121_base.input
# Add classification layers
x = Flatten()(densenet121_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='DenseNet121')
model.summary(show_trainable=True)
# Out:
# Model: "DenseNet121"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_16    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_8  │ (None, 230,     │         0 │ input_layer_1… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,408 │ zero_padding2… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_bn          │ (None, 112,     │       256 │ conv1_conv[0]… │   N   │
# │ (BatchNormalizat… │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_relu        │ (None, 112,     │         0 │ conv1_bn[0][0] │   -   │
# │ (Activation)      │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_9  │ (None, 114,     │         0 │ conv1_relu[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1             │ (None, 56, 56,  │         0 │ zero_padding2… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_bn │ (None, 56, 56,  │       256 │ pool1[0][0]    │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     8,192 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       512 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_con… │ (None, 56, 56,  │         0 │ pool1[0][0],   │   -   │
# │ (Concatenate)     │ 96)             │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_bn │ (None, 56, 56,  │       384 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    12,288 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_con… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Concatenate)     │ 128)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,384 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       512 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_con… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_bn │ (None, 56, 56,  │       640 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_c… │ (None, 56, 56,  │    20,480 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_bn │ (None, 56, 56,  │       512 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_con… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv2_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_bn │ (None, 56, 56,  │       768 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_c… │ (None, 56, 56,  │    24,576 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_bn │ (None, 56, 56,  │       512 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_con… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv2_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_bn │ (None, 56, 56,  │       896 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_c… │ (None, 56, 56,  │    28,672 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_bn │ (None, 56, 56,  │       512 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_con… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv2_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_bn          │ (None, 56, 56,  │     1,024 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_relu        │ (None, 56, 56,  │         0 │ pool2_bn[0][0] │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_conv        │ (None, 56, 56,  │    32,768 │ pool2_relu[0]… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_pool        │ (None, 28, 28,  │         0 │ pool2_conv[0]… │   -   │
# │ (AveragePooling2… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_bn │ (None, 28, 28,  │       512 │ pool2_pool[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    16,384 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_con… │ (None, 28, 28,  │         0 │ pool2_pool[0]… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_bn │ (None, 28, 28,  │       640 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    20,480 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_con… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_bn │ (None, 28, 28,  │       768 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    24,576 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_con… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_bn │ (None, 28, 28,  │       896 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    28,672 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_con… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_bn │ (None, 28, 28,  │     1,024 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_c… │ (None, 28, 28,  │    32,768 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_bn │ (None, 28, 28,  │       512 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_con… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv3_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_bn │ (None, 28, 28,  │     1,152 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_bn │ (None, 28, 28,  │       512 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_con… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv3_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_bn │ (None, 28, 28,  │     1,280 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_c… │ (None, 28, 28,  │    40,960 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_bn │ (None, 28, 28,  │       512 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_con… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv3_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_bn │ (None, 28, 28,  │     1,408 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_c… │ (None, 28, 28,  │    45,056 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_bn │ (None, 28, 28,  │       512 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_con… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv3_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_bn │ (None, 28, 28,  │     1,536 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_c… │ (None, 28, 28,  │    49,152 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_bn │ (None, 28, 28,  │       512 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_con… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv3_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │     1,664 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │    53,248 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │       512 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_2_… │ (None, 28, 28,  │    36,864 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_co… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv3_block10… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │     1,792 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │    57,344 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │       512 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_2_… │ (None, 28, 28,  │    36,864 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_co… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv3_block11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │     1,920 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │    61,440 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │       512 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_2_… │ (None, 28, 28,  │    36,864 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_co… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv3_block12… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_bn          │ (None, 28, 28,  │     2,048 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_relu        │ (None, 28, 28,  │         0 │ pool3_bn[0][0] │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_conv        │ (None, 28, 28,  │   131,072 │ pool3_relu[0]… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_pool        │ (None, 14, 14,  │         0 │ pool3_conv[0]… │   -   │
# │ (AveragePooling2… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_bn │ (None, 14, 14,  │     1,024 │ pool3_pool[0]… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │    32,768 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │       512 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_con… │ (None, 14, 14,  │         0 │ pool3_pool[0]… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_bn │ (None, 14, 14,  │     1,152 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │       512 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_con… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_bn │ (None, 14, 14,  │     1,280 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │    40,960 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │       512 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_con… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_bn │ (None, 14, 14,  │     1,408 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │    45,056 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │       512 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_con… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_bn │ (None, 14, 14,  │     1,536 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │    49,152 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │       512 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_con… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_bn │ (None, 14, 14,  │     1,664 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │    53,248 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │       512 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_con… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_bn │ (None, 14, 14,  │     1,792 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_c… │ (None, 14, 14,  │    57,344 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_bn │ (None, 14, 14,  │       512 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_con… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv4_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_bn │ (None, 14, 14,  │     1,920 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_c… │ (None, 14, 14,  │    61,440 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_bn │ (None, 14, 14,  │       512 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_con… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv4_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_bn │ (None, 14, 14,  │     2,048 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_c… │ (None, 14, 14,  │    65,536 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_bn │ (None, 14, 14,  │       512 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_con… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Concatenate)     │ 544)            │           │ conv4_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │     2,176 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 544)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │         0 │ conv4_block10… │   -   │
# │ (Activation)      │ 544)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_1_… │ (None, 14, 14,  │    69,632 │ conv4_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ...
# │ (Concatenate)     │ 736)            │           │ conv5_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_0_bn │ (None, 7, 7,    │     2,944 │ conv5_block7_… │   N   │
# │ (BatchNormalizat… │ 736)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_0_r… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Activation)      │ 736)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_c… │ (None, 7, 7,    │    94,208 │ conv5_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_bn │ (None, 7, 7,    │       512 │ conv5_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_1_r… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_2_c… │ (None, 7, 7,    │    36,864 │ conv5_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block8_con… │ (None, 7, 7,    │         0 │ conv5_block7_… │   -   │
# │ (Concatenate)     │ 768)            │           │ conv5_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_0_bn │ (None, 7, 7,    │     3,072 │ conv5_block8_… │   N   │
# │ (BatchNormalizat… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_0_r… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Activation)      │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_c… │ (None, 7, 7,    │    98,304 │ conv5_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_bn │ (None, 7, 7,    │       512 │ conv5_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_1_r… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_2_c… │ (None, 7, 7,    │    36,864 │ conv5_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block9_con… │ (None, 7, 7,    │         0 │ conv5_block8_… │   -   │
# │ (Concatenate)     │ 800)            │           │ conv5_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_0_… │ (None, 7, 7,    │     3,200 │ conv5_block9_… │   N   │
# │ (BatchNormalizat… │ 800)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_0_… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Activation)      │ 800)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │   102,400 │ conv5_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │       512 │ conv5_block10… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_1_… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_2_… │ (None, 7, 7,    │    36,864 │ conv5_block10… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block10_co… │ (None, 7, 7,    │         0 │ conv5_block9_… │   -   │
# │ (Concatenate)     │ 832)            │           │ conv5_block10… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_0_… │ (None, 7, 7,    │     3,328 │ conv5_block10… │   N   │
# │ (BatchNormalizat… │ 832)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_0_… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Activation)      │ 832)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │   106,496 │ conv5_block11… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │       512 │ conv5_block11… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_1_… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_2_… │ (None, 7, 7,    │    36,864 │ conv5_block11… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block11_co… │ (None, 7, 7,    │         0 │ conv5_block10… │   -   │
# │ (Concatenate)     │ 864)            │           │ conv5_block11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_0_… │ (None, 7, 7,    │     3,456 │ conv5_block11… │   N   │
# │ (BatchNormalizat… │ 864)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_0_… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Activation)      │ 864)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │   110,592 │ conv5_block12… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │       512 │ conv5_block12… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_1_… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_2_… │ (None, 7, 7,    │    36,864 │ conv5_block12… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block12_co… │ (None, 7, 7,    │         0 │ conv5_block11… │   -   │
# │ (Concatenate)     │ 896)            │           │ conv5_block12… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_0_… │ (None, 7, 7,    │     3,584 │ conv5_block12… │   N   │
# │ (BatchNormalizat… │ 896)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_0_… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Activation)      │ 896)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │   114,688 │ conv5_block13… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │       512 │ conv5_block13… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_1_… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_2_… │ (None, 7, 7,    │    36,864 │ conv5_block13… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block13_co… │ (None, 7, 7,    │         0 │ conv5_block12… │   -   │
# │ (Concatenate)     │ 928)            │           │ conv5_block13… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_0_… │ (None, 7, 7,    │     3,712 │ conv5_block13… │   N   │
# │ (BatchNormalizat… │ 928)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_0_… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Activation)      │ 928)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │   118,784 │ conv5_block14… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │       512 │ conv5_block14… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_1_… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_2_… │ (None, 7, 7,    │    36,864 │ conv5_block14… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block14_co… │ (None, 7, 7,    │         0 │ conv5_block13… │   -   │
# │ (Concatenate)     │ 960)            │           │ conv5_block14… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_0_… │ (None, 7, 7,    │     3,840 │ conv5_block14… │   N   │
# │ (BatchNormalizat… │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_0_… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Activation)      │ 960)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │   122,880 │ conv5_block15… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │       512 │ conv5_block15… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_1_… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_2_… │ (None, 7, 7,    │    36,864 │ conv5_block15… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block15_co… │ (None, 7, 7,    │         0 │ conv5_block14… │   -   │
# │ (Concatenate)     │ 992)            │           │ conv5_block15… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_0_… │ (None, 7, 7,    │     3,968 │ conv5_block15… │   N   │
# │ (BatchNormalizat… │ 992)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_0_… │ (None, 7, 7,    │         0 │ conv5_block16… │   -   │
# │ (Activation)      │ 992)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │   126,976 │ conv5_block16… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │       512 │ conv5_block16… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_1_… │ (None, 7, 7,    │         0 │ conv5_block16… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_2_… │ (None, 7, 7,    │    36,864 │ conv5_block16… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block16_co… │ (None, 7, 7,    │         0 │ conv5_block15… │   -   │
# │ (Concatenate)     │ 1024)           │           │ conv5_block16… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn                │ (None, 7, 7,    │     4,096 │ conv5_block16… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ relu (Activation) │ (None, 7, 7,    │         0 │ bn[0][0]       │   -   │
# │                   │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_16        │ (None, 50176)   │         0 │ relu[0][0]     │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_48 (Dense)  │ (None, 64)      │ 3,211,328 │ flatten_16[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_49 (Dense)  │ (None, 32)      │     2,080 │ dense_48[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_50 (Dense)  │ (None, 20)      │       660 │ dense_49[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 10,251,572 (39.11 MB)
#  Trainable params: 3,214,068 (12.26 MB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %% [markdown]
# ## Compile and evaluate DenseNet121

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
DenseNet121_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 208s 3s/step - accuracy: 0.0543 - loss: 9.6247

# %%
test_accuracy = DenseNet121_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
# Prepare data for plotting
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('DenseNet121 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 10251572
# Trainable parameters: 3214068
# Non-trainable parameters: 7037504

# %% [markdown]
# ## load DenseNet201 pretrained Model

# %%
from tensorflow.keras.applications import DenseNet201
densenet201_base = DenseNet201(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
densenet201_base.trainable = False
inputs=densenet201_base.input
# Add classification layers
x = Flatten()(densenet201_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='DenseNet201')
model.summary(show_trainable=True)
# Out:
# Model: "DenseNet201"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_17    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_10 │ (None, 230,     │         0 │ input_layer_1… │   -   │
# │ (ZeroPadding2D)   │ 230, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_conv        │ (None, 112,     │     9,408 │ zero_padding2… │   N   │
# │ (Conv2D)          │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_bn          │ (None, 112,     │       256 │ conv1_conv[0]… │   N   │
# │ (BatchNormalizat… │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv1_relu        │ (None, 112,     │         0 │ conv1_bn[0][0] │   -   │
# │ (Activation)      │ 112, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_11 │ (None, 114,     │         0 │ conv1_relu[0]… │   -   │
# │ (ZeroPadding2D)   │ 114, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool1             │ (None, 56, 56,  │         0 │ zero_padding2… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_bn │ (None, 56, 56,  │       256 │ pool1[0][0]    │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_0_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_c… │ (None, 56, 56,  │     8,192 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_bn │ (None, 56, 56,  │       512 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_1_r… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block1_con… │ (None, 56, 56,  │         0 │ pool1[0][0],   │   -   │
# │ (Concatenate)     │ 96)             │           │ conv2_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_bn │ (None, 56, 56,  │       384 │ conv2_block1_… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_0_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_c… │ (None, 56, 56,  │    12,288 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_1_r… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block2_con… │ (None, 56, 56,  │         0 │ conv2_block1_… │   -   │
# │ (Concatenate)     │ 128)            │           │ conv2_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_bn │ (None, 56, 56,  │       512 │ conv2_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_0_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_c… │ (None, 56, 56,  │    16,384 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_bn │ (None, 56, 56,  │       512 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_1_r… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block3_con… │ (None, 56, 56,  │         0 │ conv2_block2_… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv2_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_bn │ (None, 56, 56,  │       640 │ conv2_block3_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_0_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_c… │ (None, 56, 56,  │    20,480 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_bn │ (None, 56, 56,  │       512 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_1_r… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block4_con… │ (None, 56, 56,  │         0 │ conv2_block3_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv2_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_bn │ (None, 56, 56,  │       768 │ conv2_block4_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_0_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_c… │ (None, 56, 56,  │    24,576 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_bn │ (None, 56, 56,  │       512 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_1_r… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block5_con… │ (None, 56, 56,  │         0 │ conv2_block4_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv2_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_bn │ (None, 56, 56,  │       896 │ conv2_block5_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_0_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_c… │ (None, 56, 56,  │    28,672 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_bn │ (None, 56, 56,  │       512 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_1_r… │ (None, 56, 56,  │         0 │ conv2_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_2_c… │ (None, 56, 56,  │    36,864 │ conv2_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2_block6_con… │ (None, 56, 56,  │         0 │ conv2_block5_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv2_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_bn          │ (None, 56, 56,  │     1,024 │ conv2_block6_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_relu        │ (None, 56, 56,  │         0 │ pool2_bn[0][0] │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_conv        │ (None, 56, 56,  │    32,768 │ pool2_relu[0]… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool2_pool        │ (None, 28, 28,  │         0 │ pool2_conv[0]… │   -   │
# │ (AveragePooling2… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_bn │ (None, 28, 28,  │       512 │ pool2_pool[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_0_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_c… │ (None, 28, 28,  │    16,384 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_bn │ (None, 28, 28,  │       512 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_1_r… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block1_con… │ (None, 28, 28,  │         0 │ pool2_pool[0]… │   -   │
# │ (Concatenate)     │ 160)            │           │ conv3_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_bn │ (None, 28, 28,  │       640 │ conv3_block1_… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_0_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_c… │ (None, 28, 28,  │    20,480 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_bn │ (None, 28, 28,  │       512 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_1_r… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block2_con… │ (None, 28, 28,  │         0 │ conv3_block1_… │   -   │
# │ (Concatenate)     │ 192)            │           │ conv3_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_bn │ (None, 28, 28,  │       768 │ conv3_block2_… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_0_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_c… │ (None, 28, 28,  │    24,576 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_bn │ (None, 28, 28,  │       512 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_1_r… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block3_con… │ (None, 28, 28,  │         0 │ conv3_block2_… │   -   │
# │ (Concatenate)     │ 224)            │           │ conv3_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_bn │ (None, 28, 28,  │       896 │ conv3_block3_… │   N   │
# │ (BatchNormalizat… │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_0_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 224)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_c… │ (None, 28, 28,  │    28,672 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_bn │ (None, 28, 28,  │       512 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_1_r… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block4_con… │ (None, 28, 28,  │         0 │ conv3_block3_… │   -   │
# │ (Concatenate)     │ 256)            │           │ conv3_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_bn │ (None, 28, 28,  │     1,024 │ conv3_block4_… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_0_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_c… │ (None, 28, 28,  │    32,768 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_bn │ (None, 28, 28,  │       512 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_1_r… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block5_con… │ (None, 28, 28,  │         0 │ conv3_block4_… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv3_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_bn │ (None, 28, 28,  │     1,152 │ conv3_block5_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_0_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_bn │ (None, 28, 28,  │       512 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_1_r… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block6_con… │ (None, 28, 28,  │         0 │ conv3_block5_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv3_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_bn │ (None, 28, 28,  │     1,280 │ conv3_block6_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_0_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_c… │ (None, 28, 28,  │    40,960 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_bn │ (None, 28, 28,  │       512 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_1_r… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block7_con… │ (None, 28, 28,  │         0 │ conv3_block6_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv3_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_bn │ (None, 28, 28,  │     1,408 │ conv3_block7_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_0_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_c… │ (None, 28, 28,  │    45,056 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_bn │ (None, 28, 28,  │       512 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_1_r… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block8_con… │ (None, 28, 28,  │         0 │ conv3_block7_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv3_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_bn │ (None, 28, 28,  │     1,536 │ conv3_block8_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_0_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_c… │ (None, 28, 28,  │    49,152 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_bn │ (None, 28, 28,  │       512 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_1_r… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_2_c… │ (None, 28, 28,  │    36,864 │ conv3_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block9_con… │ (None, 28, 28,  │         0 │ conv3_block8_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv3_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │     1,664 │ conv3_block9_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_0_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │    53,248 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │       512 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_1_… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_2_… │ (None, 28, 28,  │    36,864 │ conv3_block10… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block10_co… │ (None, 28, 28,  │         0 │ conv3_block9_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv3_block10… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │     1,792 │ conv3_block10… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_0_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │    57,344 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │       512 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_1_… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_2_… │ (None, 28, 28,  │    36,864 │ conv3_block11… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block11_co… │ (None, 28, 28,  │         0 │ conv3_block10… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv3_block11… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │     1,920 │ conv3_block11… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_0_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │    61,440 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │       512 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_1_… │ (None, 28, 28,  │         0 │ conv3_block12… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_2_… │ (None, 28, 28,  │    36,864 │ conv3_block12… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv3_block12_co… │ (None, 28, 28,  │         0 │ conv3_block11… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv3_block12… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_bn          │ (None, 28, 28,  │     2,048 │ conv3_block12… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_relu        │ (None, 28, 28,  │         0 │ pool3_bn[0][0] │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_conv        │ (None, 28, 28,  │   131,072 │ pool3_relu[0]… │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ pool3_pool        │ (None, 14, 14,  │         0 │ pool3_conv[0]… │   -   │
# │ (AveragePooling2… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_bn │ (None, 14, 14,  │     1,024 │ pool3_pool[0]… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_0_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_c… │ (None, 14, 14,  │    32,768 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_bn │ (None, 14, 14,  │       512 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_1_r… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block1_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block1_con… │ (None, 14, 14,  │         0 │ pool3_pool[0]… │   -   │
# │ (Concatenate)     │ 288)            │           │ conv4_block1_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_bn │ (None, 14, 14,  │     1,152 │ conv4_block1_… │   N   │
# │ (BatchNormalizat… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_0_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_bn │ (None, 14, 14,  │       512 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_1_r… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block2_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block2_con… │ (None, 14, 14,  │         0 │ conv4_block1_… │   -   │
# │ (Concatenate)     │ 320)            │           │ conv4_block2_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_bn │ (None, 14, 14,  │     1,280 │ conv4_block2_… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_0_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_c… │ (None, 14, 14,  │    40,960 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_bn │ (None, 14, 14,  │       512 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_1_r… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block3_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block3_con… │ (None, 14, 14,  │         0 │ conv4_block2_… │   -   │
# │ (Concatenate)     │ 352)            │           │ conv4_block3_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_bn │ (None, 14, 14,  │     1,408 │ conv4_block3_… │   N   │
# │ (BatchNormalizat… │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_0_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 352)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_c… │ (None, 14, 14,  │    45,056 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_bn │ (None, 14, 14,  │       512 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_1_r… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block4_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block4_con… │ (None, 14, 14,  │         0 │ conv4_block3_… │   -   │
# │ (Concatenate)     │ 384)            │           │ conv4_block4_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_bn │ (None, 14, 14,  │     1,536 │ conv4_block4_… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_0_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_c… │ (None, 14, 14,  │    49,152 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_bn │ (None, 14, 14,  │       512 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_1_r… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block5_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block5_con… │ (None, 14, 14,  │         0 │ conv4_block4_… │   -   │
# │ (Concatenate)     │ 416)            │           │ conv4_block5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_bn │ (None, 14, 14,  │     1,664 │ conv4_block5_… │   N   │
# │ (BatchNormalizat… │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_0_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 416)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_c… │ (None, 14, 14,  │    53,248 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_bn │ (None, 14, 14,  │       512 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_1_r… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block6_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block6_con… │ (None, 14, 14,  │         0 │ conv4_block5_… │   -   │
# │ (Concatenate)     │ 448)            │           │ conv4_block6_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_bn │ (None, 14, 14,  │     1,792 │ conv4_block6_… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_0_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_c… │ (None, 14, 14,  │    57,344 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_bn │ (None, 14, 14,  │       512 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_1_r… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block7_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block7_con… │ (None, 14, 14,  │         0 │ conv4_block6_… │   -   │
# │ (Concatenate)     │ 480)            │           │ conv4_block7_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_bn │ (None, 14, 14,  │     1,920 │ conv4_block7_… │   N   │
# │ (BatchNormalizat… │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_0_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 480)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_c… │ (None, 14, 14,  │    61,440 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_bn │ (None, 14, 14,  │       512 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_1_r… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block8_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block8_con… │ (None, 14, 14,  │         0 │ conv4_block7_… │   -   │
# │ (Concatenate)     │ 512)            │           │ conv4_block8_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_bn │ (None, 14, 14,  │     2,048 │ conv4_block8_… │   N   │
# │ (BatchNormalizat… │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_0_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 512)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_c… │ (None, 14, 14,  │    65,536 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_bn │ (None, 14, 14,  │       512 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_1_r… │ (None, 14, 14,  │         0 │ conv4_block9_… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_2_c… │ (None, 14, 14,  │    36,864 │ conv4_block9_… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block9_con… │ (None, 14, 14,  │         0 │ conv4_block8_… │   -   │
# │ (Concatenate)     │ 544)            │           │ conv4_block9_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │     2,176 │ conv4_block9_… │   N   │
# │ (BatchNormalizat… │ 544)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_0_… │ (None, 14, 14,  │         0 │ conv4_block10… │   -   │
# │ (Activation)      │ 544)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv4_block10_1_… │ (None, 14, 14,  │    69,632 │ conv4_block10… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ...
# │ (Concatenate)     │ 1632)           │           │ conv5_block23… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_0_… │ (None, 7, 7,    │     6,528 │ conv5_block23… │   N   │
# │ (BatchNormalizat… │ 1632)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_0_… │ (None, 7, 7,    │         0 │ conv5_block24… │   -   │
# │ (Activation)      │ 1632)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_1_… │ (None, 7, 7,    │   208,896 │ conv5_block24… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_1_… │ (None, 7, 7,    │       512 │ conv5_block24… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_1_… │ (None, 7, 7,    │         0 │ conv5_block24… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_2_… │ (None, 7, 7,    │    36,864 │ conv5_block24… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block24_co… │ (None, 7, 7,    │         0 │ conv5_block23… │   -   │
# │ (Concatenate)     │ 1664)           │           │ conv5_block24… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_0_… │ (None, 7, 7,    │     6,656 │ conv5_block24… │   N   │
# │ (BatchNormalizat… │ 1664)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_0_… │ (None, 7, 7,    │         0 │ conv5_block25… │   -   │
# │ (Activation)      │ 1664)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_1_… │ (None, 7, 7,    │   212,992 │ conv5_block25… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_1_… │ (None, 7, 7,    │       512 │ conv5_block25… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_1_… │ (None, 7, 7,    │         0 │ conv5_block25… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_2_… │ (None, 7, 7,    │    36,864 │ conv5_block25… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block25_co… │ (None, 7, 7,    │         0 │ conv5_block24… │   -   │
# │ (Concatenate)     │ 1696)           │           │ conv5_block25… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_0_… │ (None, 7, 7,    │     6,784 │ conv5_block25… │   N   │
# │ (BatchNormalizat… │ 1696)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_0_… │ (None, 7, 7,    │         0 │ conv5_block26… │   -   │
# │ (Activation)      │ 1696)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_1_… │ (None, 7, 7,    │   217,088 │ conv5_block26… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_1_… │ (None, 7, 7,    │       512 │ conv5_block26… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_1_… │ (None, 7, 7,    │         0 │ conv5_block26… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_2_… │ (None, 7, 7,    │    36,864 │ conv5_block26… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block26_co… │ (None, 7, 7,    │         0 │ conv5_block25… │   -   │
# │ (Concatenate)     │ 1728)           │           │ conv5_block26… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_0_… │ (None, 7, 7,    │     6,912 │ conv5_block26… │   N   │
# │ (BatchNormalizat… │ 1728)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_0_… │ (None, 7, 7,    │         0 │ conv5_block27… │   -   │
# │ (Activation)      │ 1728)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_1_… │ (None, 7, 7,    │   221,184 │ conv5_block27… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_1_… │ (None, 7, 7,    │       512 │ conv5_block27… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_1_… │ (None, 7, 7,    │         0 │ conv5_block27… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_2_… │ (None, 7, 7,    │    36,864 │ conv5_block27… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block27_co… │ (None, 7, 7,    │         0 │ conv5_block26… │   -   │
# │ (Concatenate)     │ 1760)           │           │ conv5_block27… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_0_… │ (None, 7, 7,    │     7,040 │ conv5_block27… │   N   │
# │ (BatchNormalizat… │ 1760)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_0_… │ (None, 7, 7,    │         0 │ conv5_block28… │   -   │
# │ (Activation)      │ 1760)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_1_… │ (None, 7, 7,    │   225,280 │ conv5_block28… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_1_… │ (None, 7, 7,    │       512 │ conv5_block28… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_1_… │ (None, 7, 7,    │         0 │ conv5_block28… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_2_… │ (None, 7, 7,    │    36,864 │ conv5_block28… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block28_co… │ (None, 7, 7,    │         0 │ conv5_block27… │   -   │
# │ (Concatenate)     │ 1792)           │           │ conv5_block28… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_0_… │ (None, 7, 7,    │     7,168 │ conv5_block28… │   N   │
# │ (BatchNormalizat… │ 1792)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_0_… │ (None, 7, 7,    │         0 │ conv5_block29… │   -   │
# │ (Activation)      │ 1792)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_1_… │ (None, 7, 7,    │   229,376 │ conv5_block29… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_1_… │ (None, 7, 7,    │       512 │ conv5_block29… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_1_… │ (None, 7, 7,    │         0 │ conv5_block29… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_2_… │ (None, 7, 7,    │    36,864 │ conv5_block29… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block29_co… │ (None, 7, 7,    │         0 │ conv5_block28… │   -   │
# │ (Concatenate)     │ 1824)           │           │ conv5_block29… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_0_… │ (None, 7, 7,    │     7,296 │ conv5_block29… │   N   │
# │ (BatchNormalizat… │ 1824)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_0_… │ (None, 7, 7,    │         0 │ conv5_block30… │   -   │
# │ (Activation)      │ 1824)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_1_… │ (None, 7, 7,    │   233,472 │ conv5_block30… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_1_… │ (None, 7, 7,    │       512 │ conv5_block30… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_1_… │ (None, 7, 7,    │         0 │ conv5_block30… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_2_… │ (None, 7, 7,    │    36,864 │ conv5_block30… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block30_co… │ (None, 7, 7,    │         0 │ conv5_block29… │   -   │
# │ (Concatenate)     │ 1856)           │           │ conv5_block30… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_0_… │ (None, 7, 7,    │     7,424 │ conv5_block30… │   N   │
# │ (BatchNormalizat… │ 1856)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_0_… │ (None, 7, 7,    │         0 │ conv5_block31… │   -   │
# │ (Activation)      │ 1856)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_1_… │ (None, 7, 7,    │   237,568 │ conv5_block31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_1_… │ (None, 7, 7,    │       512 │ conv5_block31… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_1_… │ (None, 7, 7,    │         0 │ conv5_block31… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_2_… │ (None, 7, 7,    │    36,864 │ conv5_block31… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block31_co… │ (None, 7, 7,    │         0 │ conv5_block30… │   -   │
# │ (Concatenate)     │ 1888)           │           │ conv5_block31… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_0_… │ (None, 7, 7,    │     7,552 │ conv5_block31… │   N   │
# │ (BatchNormalizat… │ 1888)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_0_… │ (None, 7, 7,    │         0 │ conv5_block32… │   -   │
# │ (Activation)      │ 1888)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_1_… │ (None, 7, 7,    │   241,664 │ conv5_block32… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_1_… │ (None, 7, 7,    │       512 │ conv5_block32… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_1_… │ (None, 7, 7,    │         0 │ conv5_block32… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_2_… │ (None, 7, 7,    │    36,864 │ conv5_block32… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv5_block32_co… │ (None, 7, 7,    │         0 │ conv5_block31… │   -   │
# │ (Concatenate)     │ 1920)           │           │ conv5_block32… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ bn                │ (None, 7, 7,    │     7,680 │ conv5_block32… │   N   │
# │ (BatchNormalizat… │ 1920)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ relu (Activation) │ (None, 7, 7,    │         0 │ bn[0][0]       │   -   │
# │                   │ 1920)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_17        │ (None, 94080)   │         0 │ relu[0][0]     │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_51 (Dense)  │ (None, 64)      │ 6,021,184 │ flatten_17[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_52 (Dense)  │ (None, 32)      │     2,080 │ dense_51[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_53 (Dense)  │ (None, 20)      │       660 │ dense_52[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 24,345,908 (92.87 MB)
#  Trainable params: 6,023,924 (22.98 MB)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %% [markdown]
# ### Compile and evaluate Densenet201

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
DenseNet201_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 356s 5s/step - accuracy: 0.0477 - loss: 8.3910

# %%
test_accuracy = DenseNet201_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('DenseNet201 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 24345908
# Trainable parameters: 6023924
# Non-trainable parameters: 18321984

# %% [markdown]
# ### Load InceptionNetV3 pretrained mode

# %%
from tensorflow.keras.applications import InceptionV3
inceptionv3_base = InceptionV3(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
inceptionv3_base.trainable = False
inputs=inceptionv3_base.input
# Add classification layers
x = Flatten()(inceptionv3_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='InceptionV3')
model.summary(show_trainable=True)
# Out:
# Model: "InceptionV3"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_18    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_98         │ (None, 111,     │       864 │ input_layer_1… │   N   │
# │ (Conv2D)          │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 111,     │        96 │ conv2d_98[0][… │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_282    │ (None, 111,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_99         │ (None, 109,     │     9,216 │ activation_28… │   N   │
# │ (Conv2D)          │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 109,     │        96 │ conv2d_99[0][… │   N   │
# │ (BatchNormalizat… │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_283    │ (None, 109,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 109, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_100        │ (None, 109,     │    18,432 │ activation_28… │   N   │
# │ (Conv2D)          │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 109,     │       192 │ conv2d_100[0]… │   N   │
# │ (BatchNormalizat… │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_284    │ (None, 109,     │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_4   │ (None, 54, 54,  │         0 │ activation_28… │   -   │
# │ (MaxPooling2D)    │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_101        │ (None, 54, 54,  │     5,120 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 54, 54,  │       240 │ conv2d_101[0]… │   N   │
# │ (BatchNormalizat… │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_285    │ (None, 54, 54,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 80)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_102        │ (None, 52, 52,  │   138,240 │ activation_28… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 52, 52,  │       576 │ conv2d_102[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_286    │ (None, 52, 52,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_5   │ (None, 25, 25,  │         0 │ activation_28… │   -   │
# │ (MaxPooling2D)    │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_106        │ (None, 25, 25,  │    12,288 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_106[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_290    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_104        │ (None, 25, 25,  │     9,216 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_107        │ (None, 25, 25,  │    55,296 │ activation_29… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_104[0]… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_107[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_288    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_291    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 25, 25,  │         0 │ max_pooling2d… │   -   │
# │ (AveragePooling2… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_103        │ (None, 25, 25,  │    12,288 │ max_pooling2d… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_105        │ (None, 25, 25,  │    76,800 │ activation_28… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_108        │ (None, 25, 25,  │    82,944 │ activation_29… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_109        │ (None, 25, 25,  │     6,144 │ average_pooli… │   N   │
# │ (Conv2D)          │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_103[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_105[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_108[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │        96 │ conv2d_109[0]… │   N   │
# │ (BatchNormalizat… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_287    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_289    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_292    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_293    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed0            │ (None, 25, 25,  │         0 │ activation_28… │   -   │
# │ (Concatenate)     │ 256)            │           │ activation_28… │       │
# │                   │                 │           │ activation_29… │       │
# │                   │                 │           │ activation_29… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_113        │ (None, 25, 25,  │    16,384 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_113[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_297    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_111        │ (None, 25, 25,  │    12,288 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_114        │ (None, 25, 25,  │    55,296 │ activation_29… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_111[0]… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_114[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_295    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_298    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 25, 25,  │         0 │ mixed0[0][0]   │   -   │
# │ (AveragePooling2… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_110        │ (None, 25, 25,  │    16,384 │ mixed0[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_112        │ (None, 25, 25,  │    76,800 │ activation_29… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_115        │ (None, 25, 25,  │    82,944 │ activation_29… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_116        │ (None, 25, 25,  │    16,384 │ average_pooli… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_110[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_112[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_115[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_116[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_294    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_296    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_299    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_300    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed1            │ (None, 25, 25,  │         0 │ activation_29… │   -   │
# │ (Concatenate)     │ 288)            │           │ activation_29… │       │
# │                   │                 │           │ activation_29… │       │
# │                   │                 │           │ activation_30… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_120        │ (None, 25, 25,  │    18,432 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_120[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_304    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_118        │ (None, 25, 25,  │    13,824 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_121        │ (None, 25, 25,  │    55,296 │ activation_30… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       144 │ conv2d_118[0]… │   N   │
# │ (BatchNormalizat… │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_121[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_302    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 48)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_305    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 25, 25,  │         0 │ mixed1[0][0]   │   -   │
# │ (AveragePooling2… │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_117        │ (None, 25, 25,  │    18,432 │ mixed1[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_119        │ (None, 25, 25,  │    76,800 │ activation_30… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_122        │ (None, 25, 25,  │    82,944 │ activation_30… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_123        │ (None, 25, 25,  │    18,432 │ average_pooli… │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_117[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_119[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_122[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_123[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_301    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_303    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_306    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_307    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed2            │ (None, 25, 25,  │         0 │ activation_30… │   -   │
# │ (Concatenate)     │ 288)            │           │ activation_30… │       │
# │                   │                 │           │ activation_30… │       │
# │                   │                 │           │ activation_30… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_125        │ (None, 25, 25,  │    18,432 │ mixed2[0][0]   │   N   │
# │ (Conv2D)          │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       192 │ conv2d_125[0]… │   N   │
# │ (BatchNormalizat… │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_309    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 64)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_126        │ (None, 25, 25,  │    55,296 │ activation_30… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 25, 25,  │       288 │ conv2d_126[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_310    │ (None, 25, 25,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_124        │ (None, 12, 12,  │   995,328 │ mixed2[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_127        │ (None, 12, 12,  │    82,944 │ activation_31… │   N   │
# │ (Conv2D)          │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │     1,152 │ conv2d_124[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       288 │ conv2d_127[0]… │   N   │
# │ (BatchNormalizat… │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_308    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_311    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 96)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ max_pooling2d_6   │ (None, 12, 12,  │         0 │ mixed2[0][0]   │   -   │
# │ (MaxPooling2D)    │ 288)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed3            │ (None, 12, 12,  │         0 │ activation_30… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_31… │       │
# │                   │                 │           │ max_pooling2d… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_132        │ (None, 12, 12,  │    98,304 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_132[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_316    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_133        │ (None, 12, 12,  │   114,688 │ activation_31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_133[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_317    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_129        │ (None, 12, 12,  │    98,304 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_134        │ (None, 12, 12,  │   114,688 │ activation_31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_129[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_134[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_313    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_318    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_130        │ (None, 12, 12,  │   114,688 │ activation_31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_135        │ (None, 12, 12,  │   114,688 │ activation_31… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_130[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       384 │ conv2d_135[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_314    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_319    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed3[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_128        │ (None, 12, 12,  │   147,456 │ mixed3[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_131        │ (None, 12, 12,  │   172,032 │ activation_31… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_136        │ (None, 12, 12,  │   172,032 │ activation_31… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_137        │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_128[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_131[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_136[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_137[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_312    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_315    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_320    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_321    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed4            │ (None, 12, 12,  │         0 │ activation_31… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_31… │       │
# │                   │                 │           │ activation_32… │       │
# │                   │                 │           │ activation_32… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_142        │ (None, 12, 12,  │   122,880 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_142[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_326    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_143        │ (None, 12, 12,  │   179,200 │ activation_32… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_143[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_327    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_139        │ (None, 12, 12,  │   122,880 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_144        │ (None, 12, 12,  │   179,200 │ activation_32… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_139[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_144[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_323    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_328    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_140        │ (None, 12, 12,  │   179,200 │ activation_32… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_145        │ (None, 12, 12,  │   179,200 │ activation_32… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_140[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_145[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_324    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_329    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed4[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_138        │ (None, 12, 12,  │   147,456 │ mixed4[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_141        │ (None, 12, 12,  │   215,040 │ activation_32… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_146        │ (None, 12, 12,  │   215,040 │ activation_32… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_147        │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_138[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_141[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_146[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_147[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_322    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_325    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_330    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_331    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed5            │ (None, 12, 12,  │         0 │ activation_32… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_32… │       │
# │                   │                 │           │ activation_33… │       │
# │                   │                 │           │ activation_33… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_152        │ (None, 12, 12,  │   122,880 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_152[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_336    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_153        │ (None, 12, 12,  │   179,200 │ activation_33… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_153[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_337    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_149        │ (None, 12, 12,  │   122,880 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_154        │ (None, 12, 12,  │   179,200 │ activation_33… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_149[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_154[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_333    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_338    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_150        │ (None, 12, 12,  │   179,200 │ activation_33… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_155        │ (None, 12, 12,  │   179,200 │ activation_33… │   N   │
# │ (Conv2D)          │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_150[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       480 │ conv2d_155[0]… │   N   │
# │ (BatchNormalizat… │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_334    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_339    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 160)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 12, 12,  │         0 │ mixed5[0][0]   │   -   │
# │ (AveragePooling2… │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_148        │ (None, 12, 12,  │   147,456 │ mixed5[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_151        │ (None, 12, 12,  │   215,040 │ activation_33… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_156        │ (None, 12, 12,  │   215,040 │ activation_33… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_157        │ (None, 12, 12,  │   147,456 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_148[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_151[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_156[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_157[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_332    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_335    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_340    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_341    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed6            │ (None, 12, 12,  │         0 │ activation_33… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_33… │       │
# │                   │                 │           │ activation_34… │       │
# │                   │                 │           │ activation_34… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_162        │ (None, 12, 12,  │   147,456 │ mixed6[0][0]   │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_162[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_346    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_163        │ (None, 12, 12,  │   258,048 │ activation_34… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 12, 12,  │       576 │ conv2d_163[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_347    │ (None, 12, 12,  │         0 │ batch_normali… │   -   │
# ...
# │ max_pooling2d_7   │ (None, 5, 5,    │         0 │ mixed7[0][0]   │   -   │
# │ (MaxPooling2D)    │ 768)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed8            │ (None, 5, 5,    │         0 │ activation_35… │   -   │
# │ (Concatenate)     │ 1280)           │           │ activation_35… │       │
# │                   │                 │           │ max_pooling2d… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_178        │ (None, 5, 5,    │   573,440 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,344 │ conv2d_178[0]… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_362    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_175        │ (None, 5, 5,    │   491,520 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_179        │ (None, 5, 5,    │ 1,548,288 │ activation_36… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_175[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_179[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_359    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_363    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_176        │ (None, 5, 5,    │   442,368 │ activation_35… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_177        │ (None, 5, 5,    │   442,368 │ activation_35… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_180        │ (None, 5, 5,    │   442,368 │ activation_36… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_181        │ (None, 5, 5,    │   442,368 │ activation_36… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 5, 5,    │         0 │ mixed8[0][0]   │   -   │
# │ (AveragePooling2… │ 1280)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_174        │ (None, 5, 5,    │   409,600 │ mixed8[0][0]   │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_176[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_177[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_180[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_181[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_182        │ (None, 5, 5,    │   245,760 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       960 │ conv2d_174[0]… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_360    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_361    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_364    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_365    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       576 │ conv2d_182[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_358    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9_0          │ (None, 5, 5,    │         0 │ activation_36… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_36… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_6     │ (None, 5, 5,    │         0 │ activation_36… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_36… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_366    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9            │ (None, 5, 5,    │         0 │ activation_35… │   -   │
# │ (Concatenate)     │ 2048)           │           │ mixed9_0[0][0… │       │
# │                   │                 │           │ concatenate_6… │       │
# │                   │                 │           │ activation_36… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_187        │ (None, 5, 5,    │   917,504 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,344 │ conv2d_187[0]… │   N   │
# │ (BatchNormalizat… │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_371    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 448)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_184        │ (None, 5, 5,    │   786,432 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_188        │ (None, 5, 5,    │ 1,548,288 │ activation_37… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_184[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_188[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_368    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_372    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_185        │ (None, 5, 5,    │   442,368 │ activation_36… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_186        │ (None, 5, 5,    │   442,368 │ activation_36… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_189        │ (None, 5, 5,    │   442,368 │ activation_37… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_190        │ (None, 5, 5,    │   442,368 │ activation_37… │   N   │
# │ (Conv2D)          │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ average_pooling2… │ (None, 5, 5,    │         0 │ mixed9[0][0]   │   -   │
# │ (AveragePooling2… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_183        │ (None, 5, 5,    │   655,360 │ mixed9[0][0]   │   N   │
# │ (Conv2D)          │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_185[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_186[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_189[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │     1,152 │ conv2d_190[0]… │   N   │
# │ (BatchNormalizat… │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_191        │ (None, 5, 5,    │   393,216 │ average_pooli… │   N   │
# │ (Conv2D)          │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       960 │ conv2d_183[0]… │   N   │
# │ (BatchNormalizat… │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_369    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_370    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_373    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_374    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 384)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 5, 5,    │       576 │ conv2d_191[0]… │   N   │
# │ (BatchNormalizat… │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_367    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 320)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed9_1          │ (None, 5, 5,    │         0 │ activation_36… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_37… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_7     │ (None, 5, 5,    │         0 │ activation_37… │   -   │
# │ (Concatenate)     │ 768)            │           │ activation_37… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_375    │ (None, 5, 5,    │         0 │ batch_normali… │   -   │
# │ (Activation)      │ 192)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ mixed10           │ (None, 5, 5,    │         0 │ activation_36… │   -   │
# │ (Concatenate)     │ 2048)           │           │ mixed9_1[0][0… │       │
# │                   │                 │           │ concatenate_7… │       │
# │                   │                 │           │ activation_37… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_18        │ (None, 51200)   │         0 │ mixed10[0][0]  │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_54 (Dense)  │ (None, 64)      │ 3,276,864 │ flatten_18[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_55 (Dense)  │ (None, 32)      │     2,080 │ dense_54[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_56 (Dense)  │ (None, 20)      │       660 │ dense_55[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 25,082,388 (95.68 MB)
#  Trainable params: 3,279,604 (12.51 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %% [markdown]
# ### Compile and evalute the model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
inceptionv3_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.0516 - loss: 38.1822

# %%
test_accuracy = inceptionv3_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('Inceptionv3 Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 25082388
# Trainable parameters: 3279604
# Non-trainable parameters: 21802784

# %%
from tensorflow.keras.applications import Xception
xception_base = Xception(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
xception_base.trainable = False
inputs=xception_base.input
# Add classification layers
x = Flatten()(xception_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='Xception')
model.summary(show_trainable=True)
# Out:
# Model: "Xception"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_19    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1      │ (None, 111,     │       864 │ input_layer_1… │   N   │
# │ (Conv2D)          │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_bn   │ (None, 111,     │       128 │ block1_conv1[… │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv1_act  │ (None, 111,     │         0 │ block1_conv1_… │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2      │ (None, 109,     │    18,432 │ block1_conv1_… │   N   │
# │ (Conv2D)          │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_bn   │ (None, 109,     │       256 │ block1_conv2[… │   N   │
# │ (BatchNormalizat… │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block1_conv2_act  │ (None, 109,     │         0 │ block1_conv2_… │   -   │
# │ (Activation)      │ 109, 64)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1   │ (None, 109,     │     8,768 │ block1_conv2_… │   N   │
# │ (SeparableConv2D) │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv1_… │ (None, 109,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 109,     │         0 │ block2_sepcon… │   -   │
# │ (Activation)      │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2   │ (None, 109,     │    17,536 │ block2_sepcon… │   N   │
# │ (SeparableConv2D) │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_sepconv2_… │ (None, 109,     │       512 │ block2_sepcon… │   N   │
# │ (BatchNormalizat… │ 109, 128)       │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_192        │ (None, 55, 55,  │     8,192 │ block1_conv2_… │   N   │
# │ (Conv2D)          │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block2_pool       │ (None, 55, 55,  │         0 │ block2_sepcon… │   -   │
# │ (MaxPooling2D)    │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 55, 55,  │       512 │ conv2d_192[0]… │   N   │
# │ (BatchNormalizat… │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_16 (Add)      │ (None, 55, 55,  │         0 │ block2_pool[0… │   -   │
# │                   │ 128)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 55, 55,  │         0 │ add_16[0][0]   │   -   │
# │ (Activation)      │ 128)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1   │ (None, 55, 55,  │    33,920 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv1_… │ (None, 55, 55,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 55, 55,  │         0 │ block3_sepcon… │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2   │ (None, 55, 55,  │    67,840 │ block3_sepcon… │   N   │
# │ (SeparableConv2D) │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_sepconv2_… │ (None, 55, 55,  │     1,024 │ block3_sepcon… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_193        │ (None, 28, 28,  │    32,768 │ add_16[0][0]   │   N   │
# │ (Conv2D)          │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block3_pool       │ (None, 28, 28,  │         0 │ block3_sepcon… │   -   │
# │ (MaxPooling2D)    │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 28, 28,  │     1,024 │ conv2d_193[0]… │   N   │
# │ (BatchNormalizat… │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_17 (Add)      │ (None, 28, 28,  │         0 │ block3_pool[0… │   -   │
# │                   │ 256)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 28, 28,  │         0 │ add_17[0][0]   │   -   │
# │ (Activation)      │ 256)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1   │ (None, 28, 28,  │   188,672 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv1_… │ (None, 28, 28,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 28, 28,  │         0 │ block4_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2   │ (None, 28, 28,  │   536,536 │ block4_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_sepconv2_… │ (None, 28, 28,  │     2,912 │ block4_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_194        │ (None, 14, 14,  │   186,368 │ add_17[0][0]   │   N   │
# │ (Conv2D)          │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block4_pool       │ (None, 14, 14,  │         0 │ block4_sepcon… │   -   │
# │ (MaxPooling2D)    │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 14, 14,  │     2,912 │ conv2d_194[0]… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_18 (Add)      │ (None, 14, 14,  │         0 │ block4_pool[0… │   -   │
# │                   │ 728)            │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 14, 14,  │         0 │ add_18[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv1_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv2_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3   │ (None, 14, 14,  │   536,536 │ block5_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block5_sepconv3_… │ (None, 14, 14,  │     2,912 │ block5_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_19 (Add)      │ (None, 14, 14,  │         0 │ block5_sepcon… │   -   │
# │                   │ 728)            │           │ add_18[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 14, 14,  │         0 │ add_19[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv1_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv2_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3   │ (None, 14, 14,  │   536,536 │ block6_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block6_sepconv3_… │ (None, 14, 14,  │     2,912 │ block6_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_20 (Add)      │ (None, 14, 14,  │         0 │ block6_sepcon… │   -   │
# │                   │ 728)            │           │ add_19[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 14, 14,  │         0 │ add_20[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv1_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv2_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3   │ (None, 14, 14,  │   536,536 │ block7_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block7_sepconv3_… │ (None, 14, 14,  │     2,912 │ block7_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_21 (Add)      │ (None, 14, 14,  │         0 │ block7_sepcon… │   -   │
# │                   │ 728)            │           │ add_20[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 14, 14,  │         0 │ add_21[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv1_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv2_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3   │ (None, 14, 14,  │   536,536 │ block8_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block8_sepconv3_… │ (None, 14, 14,  │     2,912 │ block8_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_22 (Add)      │ (None, 14, 14,  │         0 │ block8_sepcon… │   -   │
# │                   │ 728)            │           │ add_21[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 14, 14,  │         0 │ add_22[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv1_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv2_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3   │ (None, 14, 14,  │   536,536 │ block9_sepcon… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block9_sepconv3_… │ (None, 14, 14,  │     2,912 │ block9_sepcon… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_23 (Add)      │ (None, 14, 14,  │         0 │ block9_sepcon… │   -   │
# │                   │ 728)            │           │ add_22[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 14, 14,  │         0 │ add_23[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv1… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv2… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3  │ (None, 14, 14,  │   536,536 │ block10_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block10_sepconv3… │ (None, 14, 14,  │     2,912 │ block10_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_24 (Add)      │ (None, 14, 14,  │         0 │ block10_sepco… │   -   │
# │                   │ 728)            │           │ add_23[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 14, 14,  │         0 │ add_24[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv1… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv2… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3  │ (None, 14, 14,  │   536,536 │ block11_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block11_sepconv3… │ (None, 14, 14,  │     2,912 │ block11_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_25 (Add)      │ (None, 14, 14,  │         0 │ block11_sepco… │   -   │
# │                   │ 728)            │           │ add_24[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 14, 14,  │         0 │ add_25[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv1… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv2… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3  │ (None, 14, 14,  │   536,536 │ block12_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block12_sepconv3… │ (None, 14, 14,  │     2,912 │ block12_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_26 (Add)      │ (None, 14, 14,  │         0 │ block12_sepco… │   -   │
# │                   │ 728)            │           │ add_25[0][0]   │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 14, 14,  │         0 │ add_26[0][0]   │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1  │ (None, 14, 14,  │   536,536 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv1… │ (None, 14, 14,  │     2,912 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 14, 14,  │         0 │ block13_sepco… │   -   │
# │ (Activation)      │ 728)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2  │ (None, 14, 14,  │   752,024 │ block13_sepco… │   N   │
# │ (SeparableConv2D) │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_sepconv2… │ (None, 14, 14,  │     4,096 │ block13_sepco… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ conv2d_195        │ (None, 7, 7,    │   745,472 │ add_26[0][0]   │   N   │
# │ (Conv2D)          │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block13_pool      │ (None, 7, 7,    │         0 │ block13_sepco… │   -   │
# │ (MaxPooling2D)    │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ batch_normalizat… │ (None, 7, 7,    │     4,096 │ conv2d_195[0]… │   N   │
# │ (BatchNormalizat… │ 1024)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_27 (Add)      │ (None, 7, 7,    │         0 │ block13_pool[… │   -   │
# │                   │ 1024)           │           │ batch_normali… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1  │ (None, 7, 7,    │ 1,582,080 │ add_27[0][0]   │   N   │
# │ (SeparableConv2D) │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 7, 7,    │     6,144 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv1… │ (None, 7, 7,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 1536)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2  │ (None, 7, 7,    │ 3,159,552 │ block14_sepco… │   N   │
# │ (SeparableConv2D) │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 7, 7,    │     8,192 │ block14_sepco… │   N   │
# │ (BatchNormalizat… │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ block14_sepconv2… │ (None, 7, 7,    │         0 │ block14_sepco… │   -   │
# │ (Activation)      │ 2048)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_19        │ (None, 100352)  │         0 │ block14_sepco… │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_57 (Dense)  │ (None, 64)      │ 6,422,592 │ flatten_19[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_58 (Dense)  │ (None, 32)      │     2,080 │ dense_57[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_59 (Dense)  │ (None, 20)      │       660 │ dense_58[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 27,286,812 (104.09 MB)
#  Trainable params: 6,425,332 (24.51 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
xception_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 239s 4s/step - accuracy: 0.0308 - loss: 10.9840

# %%
test_accuracy = xception_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('Xception Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 7584136
# Trainable parameters: 3314420
# Non-trainable parameters: 4269716

# %% [markdown]
# ### Load NASnetMobile model

# %%
from tensorflow.keras.applications import  NASNetMobile
nasnet_base = NASNetMobile(weights='imagenet', include_top=False,input_shape=(224, 224, 3))
nasnet_base.trainable = False
inputs=nasnet_base.input
# Add classification layers
x = Flatten()(nasnet_base.output)
x = Dense(64, activation='relu')(x)
x = Dense(32, activation='relu')(x)
outputs = Dense(20, activation='softmax')(x)
model = Model(inputs, outputs, name='NASNetMobile')
model.summary(show_trainable=True)
# Out:
# Model: "NASNetMobile"
# ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━┓
# ┃ Layer (type)      ┃ Output Shape    ┃   Param # ┃ Connected to   ┃ Trai… ┃
# ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━┩
# │ input_layer_20    │ (None, 224,     │         0 │ -              │   -   │
# │ (InputLayer)      │ 224, 3)         │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_conv1        │ (None, 111,     │       864 │ input_layer_2… │   N   │
# │ (Conv2D)          │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ stem_bn1          │ (None, 111,     │       128 │ stem_conv1[0]… │   N   │
# │ (BatchNormalizat… │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_376    │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_conv_1… │ (None, 111,     │       352 │ activation_37… │   N   │
# │ (Conv2D)          │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_bn_1_s… │ (None, 111,     │        44 │ reduction_con… │   N   │
# │ (BatchNormalizat… │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_377    │ (None, 111,     │         0 │ reduction_bn_… │   -   │
# │ (Activation)      │ 111, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_379    │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 115,     │         0 │ activation_37… │   -   │
# │ (ZeroPadding2D)   │ 115, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 117,     │         0 │ activation_37… │   -   │
# │ (ZeroPadding2D)   │ 117, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │       396 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,920 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_378    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_380    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       396 │ activation_37… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       660 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_381    │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 117,     │         0 │ activation_38… │   -   │
# │ (ZeroPadding2D)   │ 117, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_383    │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_1_… │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,920 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 115,     │         0 │ activation_38… │   -   │
# │ (ZeroPadding2D)   │ 115, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_385    │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │     1,152 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │       220 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_382    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_pad_1_… │ (None, 113,     │         0 │ reduction_bn_… │   -   │
# │ (ZeroPadding2D)   │ 113, 11)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       660 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_384    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_386    │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left2_… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       396 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │       220 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_relu_1_st… │ (None, 111,     │         0 │ stem_bn1[0][0] │   -   │
# │ (Activation)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_2_… │ (None, 56, 56,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left3_… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (AveragePooling2… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left4_… │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (AveragePooling2… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 56, 56,  │        44 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_right5… │ (None, 56, 56,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_12 │ (None, 112,     │         0 │ adjust_relu_1… │   -   │
# │ (ZeroPadding2D)   │ 112, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add3_s… │ (None, 56, 56,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 11)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_28 (Add)      │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │                   │ 11)             │           │ reduction_lef… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add4_s… │ (None, 56, 56,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 11)             │           │ reduction_rig… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ cropping2d_4      │ (None, 111,     │         0 │ zero_padding2… │   -   │
# │ (Cropping2D)      │ 111, 32)        │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_concat… │ (None, 56, 56,  │         0 │ reduction_add… │   -   │
# │ (Concatenate)     │ 44)             │           │ reduction_add… │       │
# │                   │                 │           │ add_28[0][0],  │       │
# │                   │                 │           │ reduction_add… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 56, 56,  │         0 │ adjust_relu_1… │   -   │
# │ (AveragePooling2… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 56, 56,  │         0 │ cropping2d_4[… │   -   │
# │ (AveragePooling2… │ 32)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_387    │ (None, 56, 56,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_1_st… │ (None, 56, 56,  │       352 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_2_st… │ (None, 56, 56,  │       352 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 11)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_conv_1… │ (None, 56, 56,  │       968 │ activation_38… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_8     │ (None, 56, 56,  │         0 │ adjust_conv_1… │   -   │
# │ (Concatenate)     │ 22)             │           │ adjust_conv_2… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_bn_1_s… │ (None, 56, 56,  │        88 │ reduction_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_stem_2  │ (None, 56, 56,  │        88 │ concatenate_8… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_388    │ (None, 56, 56,  │         0 │ reduction_bn_… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_390    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 59, 59,  │         0 │ activation_38… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 61, 61,  │         0 │ activation_39… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,034 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,562 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_389    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_391    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,034 │ activation_38… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,562 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_392    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 61, 61,  │         0 │ activation_39… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_394    │ (None, 56, 56,  │         0 │ adjust_bn_ste… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_1_… │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,562 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 59, 59,  │         0 │ activation_39… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_396    │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     1,034 │ separable_con… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       682 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_393    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_pad_1_… │ (None, 57, 57,  │         0 │ reduction_bn_… │   -   │
# │ (ZeroPadding2D)   │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,562 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_395    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_397    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left2_… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     1,034 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       682 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_relu_1_0   │ (None, 56, 56,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add_2_… │ (None, 28, 28,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left3_… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (AveragePooling2… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_left4_… │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (AveragePooling2… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │        88 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_right5… │ (None, 28, 28,  │         0 │ reduction_pad… │   -   │
# │ (MaxPooling2D)    │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ zero_padding2d_13 │ (None, 57, 57,  │         0 │ adjust_relu_1… │   -   │
# │ (ZeroPadding2D)   │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add3_s… │ (None, 28, 28,  │         0 │ reduction_lef… │   -   │
# │ (Add)             │ 22)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ add_29 (Add)      │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │                   │ 22)             │           │ reduction_lef… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_add4_s… │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 22)             │           │ reduction_rig… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ cropping2d_5      │ (None, 56, 56,  │         0 │ zero_padding2… │   -   │
# │ (Cropping2D)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ reduction_concat… │ (None, 28, 28,  │         0 │ reduction_add… │   -   │
# │ (Concatenate)     │ 88)             │           │ reduction_add… │       │
# │                   │                 │           │ add_29[0][0],  │       │
# │                   │                 │           │ reduction_add… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 28, 28,  │         0 │ adjust_relu_1… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_avg_pool_… │ (None, 28, 28,  │         0 │ cropping2d_5[… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_1_0   │ (None, 28, 28,  │       968 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_2_0   │ (None, 28, 28,  │       968 │ adjust_avg_po… │   N   │
# │ (Conv2D)          │ 22)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_398    │ (None, 28, 28,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ concatenate_9     │ (None, 28, 28,  │         0 │ adjust_conv_1… │   -   │
# │ (Concatenate)     │ 44)             │           │ adjust_conv_2… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_0   │ (None, 28, 28,  │     3,872 │ activation_39… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_0       │ (None, 28, 28,  │       176 │ concatenate_9… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_0     │ (None, 28, 28,  │       176 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_399    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_401    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_403    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_405    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_407    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_39… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_400    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_402    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_404    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_406    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_408    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_40… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_0    │ (None, 28, 28,  │         0 │ normal_bn_1_0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_0    │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_0   │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_0    │ (None, 28, 28,  │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 44)             │           │ adjust_bn_0[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_0    │ (None, 28, 28,  │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 44)             │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_0    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ normal_bn_1_0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_0   │ (None, 28, 28,  │         0 │ adjust_bn_0[0… │   -   │
# │ (Concatenate)     │ 264)            │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_409    │ (None, 28, 28,  │         0 │ reduction_con… │   -   │
# │ (Activation)      │ 88)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_410    │ (None, 28, 28,  │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 264)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_proj… │ (None, 28, 28,  │     3,872 │ activation_40… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_1   │ (None, 28, 28,  │    11,616 │ activation_41… │   N   │
# │ (Conv2D)          │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_1       │ (None, 28, 28,  │       176 │ adjust_conv_p… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_1     │ (None, 28, 28,  │       176 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_411    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_413    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_415    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_417    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_419    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     3,036 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │     2,332 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_412    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_414    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_416    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_418    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_420    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Activation)      │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     3,036 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_41… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │     2,332 │ activation_42… │   N   │
# │ (SeparableConv2D) │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_1    │ (None, 28, 28,  │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_1    │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_1   │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (AveragePooling2… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 28, 28,  │       176 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 44)             │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_1    │ (None, 28, 28,  │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 44)             │           │ adjust_bn_1[0… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_1    │ (None, 28, 28,  │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 44)             │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_1    │ (None, 28, 28,  │         0 │ separable_con… │   -   │
# │ (Add)             │ 44)             │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_1   │ (None, 28, 28,  │         0 │ adjust_bn_1[0… │   -   │
# │ (Concatenate)     │ 264)            │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# ...
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_54… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_54… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_11   │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_11   │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_11  │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_11   │ (None, 7, 7,    │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 176)            │           │ adjust_bn_11[… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_11   │ (None, 7, 7,    │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 176)            │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_11   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_11  │ (None, 7, 7,    │         0 │ adjust_bn_11[… │   -   │
# │ (Concatenate)     │ 1056)           │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_551    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_552    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_conv_proj… │ (None, 7, 7,    │   185,856 │ activation_55… │   N   │
# │ (Conv2D)          │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_conv_1_12  │ (None, 7, 7,    │   185,856 │ activation_55… │   N   │
# │ (Conv2D)          │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ adjust_bn_12      │ (None, 7, 7,    │       704 │ adjust_conv_p… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_bn_1_12    │ (None, 7, 7,    │       704 │ normal_conv_1… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_553    │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_555    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_557    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_559    │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_561    │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    35,376 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    35,376 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │    32,560 │ activation_56… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_1… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_554    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_556    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_558    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_560    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_562    │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Activation)      │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    35,376 │ activation_55… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_56… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │    32,560 │ activation_56… │   N   │
# │ (SeparableConv2D) │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left3_12   │ (None, 7, 7,    │         0 │ normal_bn_1_1… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_left4_12   │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_right4_12  │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (AveragePooling2… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ separable_conv_2… │ (None, 7, 7,    │       704 │ separable_con… │   N   │
# │ (BatchNormalizat… │ 176)            │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_1_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_2_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ separable_con… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_3_12   │ (None, 7, 7,    │         0 │ normal_left3_… │   -   │
# │ (Add)             │ 176)            │           │ adjust_bn_12[… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_4_12   │ (None, 7, 7,    │         0 │ normal_left4_… │   -   │
# │ (Add)             │ 176)            │           │ normal_right4… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_add_5_12   │ (None, 7, 7,    │         0 │ separable_con… │   -   │
# │ (Add)             │ 176)            │           │ normal_bn_1_1… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ normal_concat_12  │ (None, 7, 7,    │         0 │ adjust_bn_12[… │   -   │
# │ (Concatenate)     │ 1056)           │           │ normal_add_1_… │       │
# │                   │                 │           │ normal_add_2_… │       │
# │                   │                 │           │ normal_add_3_… │       │
# │                   │                 │           │ normal_add_4_… │       │
# │                   │                 │           │ normal_add_5_… │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ activation_563    │ (None, 7, 7,    │         0 │ normal_concat… │   -   │
# │ (Activation)      │ 1056)           │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ flatten_20        │ (None, 51744)   │         0 │ activation_56… │   -   │
# │ (Flatten)         │                 │           │                │       │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_60 (Dense)  │ (None, 64)      │ 3,311,680 │ flatten_20[0]… │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_61 (Dense)  │ (None, 32)      │     2,080 │ dense_60[0][0] │   Y   │
# ├───────────────────┼─────────────────┼───────────┼────────────────┼───────┤
# │ dense_62 (Dense)  │ (None, 20)      │       660 │ dense_61[0][0] │   Y   │
# └───────────────────┴─────────────────┴───────────┴────────────────┴───────┘
#  Total params: 7,584,136 (28.93 MB)
#  Trainable params: 3,314,420 (12.64 MB)
#  Non-trainable params: 4,269,716 (16.29 MB)

# %% [markdown]
# ### Evaluate the model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
nasnet_history = model.evaluate(testX_preprocessed, testY)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.0499 - loss: 13.5435

# %%
test_accuracy = nasnet_history[1] * 100
total_params = model.count_params()
trainable_params = np.sum([np.prod(v.shape) for v in model.trainable_variables])
non_trainable_params = total_params - trainable_params
print(f'Total parameters: {total_params}')
print(f'Trainable parameters: {trainable_params}')
print(f'Non-trainable parameters: {non_trainable_params}')
labels = ['Total Params', 'Trainable Params', 'Non-trainable Params', 'Test Accuracy (%)']
values = [total_params, trainable_params, non_trainable_params, test_accuracy]
colors = ['#1f77b4', '#2ca02c', '#ff7f0e', '#d62728']
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, values, color=colors)
plt.yscale('log')
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, f'{yval:,.2f}', ha='center', va='bottom', fontsize=9)
plt.title('NASNet Model Parameters and Test Accuracy')
plt.ylabel('Value')
plt.tight_layout()
plt.show()
# Out:
# Total parameters: 7584136
# Trainable parameters: 3314420
# Non-trainable parameters: 4269716
