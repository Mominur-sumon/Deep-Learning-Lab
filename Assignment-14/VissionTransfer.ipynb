# %% [markdown]
# ## Import Necessary Modules

# %%
# ===================== Imports =====================
import os
import random
import time
import warnings
import shutil

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, models, optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess

from sklearn.model_selection import train_test_split

# ===================== Configuration =====================
# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set seeds for reproducibility
SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# ===================== TensorFlow Info =====================
print("TensorFlow version:", tf.__version__)
gpu_devices = tf.config.list_physical_devices('GPU')
print("GPU available:", gpu_devices if gpu_devices else "No GPU detected")
# Out:
# TensorFlow version: 2.19.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Data Preparation

# %%
import os
import shutil
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ===================== Config =====================
DATA_URL = "http://cs231n.stanford.edu/tiny-imagenet-200.zip"
DATA_ZIP = "tiny-imagenet-200.zip"
EXTRACT_DIR = "/content/tiny-imagenet"
SUBSET_DIR = "/content/imagenet_20"
TARGET_SIZE = (64, 64)
BATCH_SIZE_TRAIN = 64
BATCH_SIZE_TEST = 32
NUM_CLASSES = 20
SEED = 42

# ===================== Download & Extract =====================
def download_and_extract_tiny_imagenet(url=DATA_URL, zip_path=DATA_ZIP, extract_dir=EXTRACT_DIR):
    if not os.path.exists(extract_dir):
        os.system(f"wget -q {url}")
        os.system(f"unzip -q {zip_path} -d {extract_dir}")
        print(f"Extracted Tiny-ImageNet to {extract_dir}")
    else:
        print(f"{extract_dir} already exists. Skipping download.")

download_and_extract_tiny_imagenet()

# ===================== Create 20-Class Subset =====================
def create_subset(selected_classes=NUM_CLASSES, train_dir=os.path.join(EXTRACT_DIR, "tiny-imagenet-200/train"),
                val_dir=os.path.join(EXTRACT_DIR, "tiny-imagenet-200/val"), subset_dir=SUBSET_DIR):

    # Create train subset
    all_classes = sorted(os.listdir(train_dir))
    selected_classes = all_classes[:selected_classes]
    subset_train_dir = os.path.join(subset_dir, "train")
    os.makedirs(subset_train_dir, exist_ok=True)

    for cls in selected_classes:
        shutil.copytree(os.path.join(train_dir, cls), os.path.join(subset_train_dir, cls), dirs_exist_ok=True)

    # Create validation subset
    val_annotations = pd.read_csv(
        os.path.join(val_dir, "val_annotations.txt"),
        sep='\t', names=['file', 'class', 'x1', 'y1', 'x2', 'y2']
    )
    subset_val_dir = os.path.join(subset_dir, "val")
    os.makedirs(subset_val_dir, exist_ok=True)

    for cls in selected_classes:
        os.makedirs(os.path.join(subset_val_dir, cls), exist_ok=True)

    val_images_dir = os.path.join(val_dir, "images")
    for _, row in val_annotations.iterrows():
        if row['class'] in selected_classes:
            shutil.copy(
                os.path.join(val_images_dir, row['file']),
                os.path.join(subset_val_dir, row['class'], row['file'])
            )
    print(f"Created 20-class subset at {subset_dir}")

create_subset()

# ===================== Data Generators =====================
def create_data_generators(subset_dir=SUBSET_DIR, target_size=TARGET_SIZE, batch_size_train=BATCH_SIZE_TRAIN,
                           batch_size_test=BATCH_SIZE_TEST, seed=SEED):

    # Training & validation generator with augmentation
    train_datagen = ImageDataGenerator(
        preprocessing_function=resnet_preprocess,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True,
        validation_split=0.1
    )

    train_generator = train_datagen.flow_from_directory(
        os.path.join(subset_dir, "train"),
        target_size=target_size,
        batch_size=batch_size_train,
        class_mode='categorical',
        subset='training',
        shuffle=True,
        seed=seed
    )

    val_generator = train_datagen.flow_from_directory(
        os.path.join(subset_dir, "train"),
        target_size=target_size,
        batch_size=batch_size_train,
        class_mode='categorical',
        subset='validation',
        shuffle=False,
        seed=seed
    )

    # Test generator without augmentation
    test_datagen = ImageDataGenerator(preprocessing_function=resnet_preprocess)
    test_generator = test_datagen.flow_from_directory(
        os.path.join(subset_dir, "val"),
        target_size=target_size,
        batch_size=batch_size_test,
        class_mode='categorical',
        shuffle=False
    )

    return train_generator, val_generator, test_generator

train_gen, val_gen, test_gen = create_data_generators()

# ===================== Convert Generators to Arrays =====================
def generator_to_arrays(generator):
    x_list, y_list = [], []
    for batch_x, batch_y in generator:
        x_list.append(batch_x)
        y_list.append(batch_y)
        if len(x_list) * generator.batch_size >= generator.samples:
            break
    return np.concatenate(x_list), np.concatenate(y_list)

x_train, y_train = generator_to_arrays(train_gen)
x_val, y_val = generator_to_arrays(val_gen)
x_test, y_test = generator_to_arrays(test_gen)

# ===================== Print Dataset Info =====================
print(f"Training data shape: {x_train.shape}")
print(f"Validation data shape: {x_val.shape}")
print(f"Test data shape: {x_test.shape}")
print(f"Number of classes: {len(train_gen.class_indices)}")
# Out:
# Extracted Tiny-ImageNet to /content/tiny-imagenet
# Created 20-class subset at /content/imagenet_20
# Found 9000 images belonging to 20 classes.
# Found 1000 images belonging to 20 classes.
# Found 1000 images belonging to 20 classes.
# Training data shape: (9000, 64, 64, 3)
# Validation data shape: (1000, 64, 64, 3)
# Test data shape: (1000, 64, 64, 3)
# Number of classes: 20

# %% [markdown]
# ## Data Visualization

# %%
# Load wnid → human-readable class mapping (first name only)
wnid_to_label = {}
with open("/content/tiny-imagenet/tiny-imagenet-200/words.txt", "r") as f:
    for line in f:
        wnid, label = line.strip().split("\t")
        wnid_to_label[wnid] = label.split(',')[0]  # take only the first name

import matplotlib.pyplot as plt

# Map numeric label → wnid → human-readable name
numeric_to_wnid = {v: k for k, v in train_gen.class_indices.items()}

num_images = 10
indices = np.random.choice(x_train.shape[0], num_images, replace=False)
images = x_train[indices]
labels = y_train[indices]
label_indices = np.argmax(labels, axis=1)

# Undo preprocessing for visualization if using resnet_preprocess
images = images.copy()
images += 1.0
images *= 127.5
images = np.clip(images, 0, 255).astype('uint8')

plt.figure(figsize=(15, 6))
for i in range(num_images):
    plt.subplot(2, 5, i + 1)
    plt.imshow(images[i])
    wnid = numeric_to_wnid[label_indices[i]]
    plt.title(wnid_to_label.get(wnid, wnid), fontsize=10)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Training function

# %%
# ===================== Training Function =====================
def train_and_evaluate(model, model_name, x_train, y_train, x_val, y_val, x_test, y_test,
                    epochs=20, batch_size=64, learning_rate=0.001):
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    callbacks = [
        keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=3, min_lr=1e-6)
    ]
    start_time = time.time()
    history = model.fit(
        x_train.astype('float32'), y_train.astype('float32'),
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_val.astype('float32'), y_val.astype('float32')),
        callbacks=callbacks,
        verbose=1
    )
    training_time = time.time() - start_time
    test_loss, test_acc = model.evaluate(x_test.astype('float32'), y_test.astype('float32'), verbose=0)
    print(f"{model_name} - Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")
    print(f"{model_name} - Training Time: {training_time:.2f} seconds")
    return history, test_acc, test_loss, training_time

# %% [markdown]
# ## Ploting Training Curve

# %%
# ===================== Plot Training Curves =====================
def plot_training_history(history):
    # Accuracy plot
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss plot
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# ## VIT Model

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import time
import matplotlib.pyplot as plt
import numpy as np

# ===================== Patch Extraction Layer =====================
class Patches(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# ===================== Patch Encoder Layer =====================
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# ===================== MLP block =====================
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# ===================== Create ViT Model =====================
def create_vit_classifier(
    input_shape=(64, 64, 3),
    patch_size=4,
    num_patches=(64 // 4) ** 2,
    projection_dim=64,
    num_heads=4,
    transformer_layers=4,
    mlp_head_units=[128, 64],
    num_classes=20,
    positional_embedding_type="learned"
):
    inputs = layers.Input(shape=input_shape)
    x = layers.Rescaling(1.0/255)(inputs)
    patches = Patches(patch_size)(x)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Transformer blocks
    for _ in range(transformer_layers):
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=projection_dim, dropout=0.1)(x1, x1)
        x2 = layers.Add()([attention_output, encoded_patches])
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = mlp(x3, hidden_units=mlp_head_units, dropout_rate=0.1)
        encoded_patches = layers.Add()([x3, x2])

    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.GlobalAveragePooling1D()(representation)
    representation = layers.Dropout(0.5)(representation)
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    outputs = layers.Dense(num_classes, activation="softmax")(features)

    model = keras.Model(inputs=inputs, outputs=outputs, name="ViT_Classifier")
    return model

# %%
# ===================== Example Usage =====================
vit_model = create_vit_classifier()
history_vit, test_acc_vit, test_loss_vit, training_time_vit = train_and_evaluate(
    vit_model, "ViT_Classifier",
    x_train, y_train,
    x_val, y_val,
    x_test, y_test,
    epochs=20,
    batch_size=64,
    learning_rate=0.001
)

# Plot training history
plot_training_history(history_vit)
# Out:
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 59s 213ms/step - accuracy: 0.0710 - loss: 3.0666 - val_accuracy: 0.1350 - val_loss: 2.8336 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 43s 61ms/step - accuracy: 0.1037 - loss: 2.9082 - val_accuracy: 0.1700 - val_loss: 2.7933 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.1363 - loss: 2.8260 - val_accuracy: 0.1770 - val_loss: 2.7033 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.1518 - loss: 2.7647 - val_accuracy: 0.1730 - val_loss: 2.7030 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - accuracy: 0.1658 - loss: 2.7017 - val_accuracy: 0.2060 - val_loss: 2.6122 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.1793 - loss: 2.6735 - val_accuracy: 0.2130 - val_loss: 2.5586 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.1813 - loss: 2.6436 - val_accuracy: 0.1990 - val_loss: 2.5916 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - accuracy: 0.2015 - loss: 2.6033 - val_accuracy: 0.2070 - val_loss: 2.5470 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.2112 - loss: 2.5525 - val_accuracy: 0.1970 - val_loss: 2.5161 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2241 - loss: 2.5466 - val_accuracy: 0.1980 - val_loss: 2.5071 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2234 - loss: 2.5044 - val_accuracy: 0.1970 - val_loss: 2.5337 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.2359 - loss: 2.4946 - val_accuracy: 0.2120 - val_loss: 2.5231 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2397 - loss: 2.4893 - val_accuracy: 0.2290 - val_loss: 2.4913 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.2434 - loss: 2.4622 - val_accuracy: 0.2200 - val_loss: 2.4771 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.2532 - loss: 2.4415 - val_accuracy: 0.2380 - val_loss: 2.4564 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.2530 - loss: 2.4199 - val_accuracy: 0.2270 - val_loss: 2.4480 - learning_rate: 0.0010
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - accuracy: 0.2660 - loss: 2.3675 - val_accuracy: 0.2210 - val_loss: 2.4680 - learning_rate: 0.0010
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2620 - loss: 2.3974 - val_accuracy: 0.2250 - val_loss: 2.4326 - learning_rate: 0.0010
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.2720 - loss: 2.3626 - val_accuracy: 0.2380 - val_loss: 2.4532 - learning_rate: 0.0010
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.2600 - loss: 2.3612 - val_accuracy: 0.2450 - val_loss: 2.4218 - learning_rate: 0.0010
# ViT_Classifier - Test Accuracy: 0.2380, Test Loss: 2.4231
# ViT_Classifier - Training Time: 276.37 seconds

# %% [markdown]
# ## FCNN

# %%
# ===================== Fully Connected Feed-Forward Network =====================
def create_fcfnn(input_shape=(64,64,3), hidden_units=[512, 256, 128], num_classes=20):
    inputs = keras.Input(shape=input_shape)
    x = layers.Rescaling(1./255)(inputs)
    x = layers.Flatten()(x)
    for units in hidden_units:
        x = layers.Dense(units, activation='relu')(x)
        x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = keras.Model(inputs=inputs, outputs=outputs, name="FCFNN")
    return model

# %%
# Create the FCFNN model
fcfnn_model = create_fcfnn(input_shape=(64, 64, 3), hidden_units=[512, 256, 128], num_classes=20)

# Train and evaluate
history_fcfnn, test_acc_fcfnn, test_loss_fcfnn, training_time_fcfnn = train_and_evaluate(
    fcfnn_model, "FCFNN_Classifier",
    x_train, y_train,
    x_val, y_val,
    x_test, y_test,
    epochs=20,
    batch_size=64,
    learning_rate=0.001
)

# Plot training history
plot_training_history(history_fcfnn)
# Out:
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.0851 - loss: 3.3478 - val_accuracy: 0.1330 - val_loss: 2.8357 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.1222 - loss: 2.8987 - val_accuracy: 0.1480 - val_loss: 2.8141 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1374 - loss: 2.8229 - val_accuracy: 0.1550 - val_loss: 2.7756 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1483 - loss: 2.7764 - val_accuracy: 0.1690 - val_loss: 2.7484 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.1557 - loss: 2.7528 - val_accuracy: 0.1750 - val_loss: 2.7186 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1732 - loss: 2.7063 - val_accuracy: 0.1780 - val_loss: 2.6860 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1793 - loss: 2.6766 - val_accuracy: 0.1910 - val_loss: 2.6750 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1880 - loss: 2.6465 - val_accuracy: 0.1900 - val_loss: 2.6619 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.1979 - loss: 2.6335 - val_accuracy: 0.1940 - val_loss: 2.6803 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2036 - loss: 2.6018 - val_accuracy: 0.2020 - val_loss: 2.6471 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2099 - loss: 2.5903 - val_accuracy: 0.1950 - val_loss: 2.6500 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2166 - loss: 2.5644 - val_accuracy: 0.2120 - val_loss: 2.6428 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2167 - loss: 2.5676 - val_accuracy: 0.2000 - val_loss: 2.6581 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2274 - loss: 2.5095 - val_accuracy: 0.2060 - val_loss: 2.6554 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2314 - loss: 2.4982 - val_accuracy: 0.1960 - val_loss: 2.6518 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.2498 - loss: 2.4518 - val_accuracy: 0.2140 - val_loss: 2.6115 - learning_rate: 1.0000e-04
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2611 - loss: 2.3842 - val_accuracy: 0.2140 - val_loss: 2.6109 - learning_rate: 1.0000e-04
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2641 - loss: 2.3552 - val_accuracy: 0.2170 - val_loss: 2.6175 - learning_rate: 1.0000e-04
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2762 - loss: 2.3416 - val_accuracy: 0.2220 - val_loss: 2.6173 - learning_rate: 1.0000e-04
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.2736 - loss: 2.3217 - val_accuracy: 0.2250 - val_loss: 2.6124 - learning_rate: 1.0000e-04
# FCFNN_Classifier - Test Accuracy: 0.2260, Test Loss: 2.5353
# FCFNN_Classifier - Training Time: 33.10 seconds

# %% [markdown]
# ## CNN

# %%
# ===================== CNN-based Classifier =====================
def create_cnn(input_shape=(64,64,3), num_classes=20):
    inputs = keras.Input(shape=input_shape)
    x = layers.Rescaling(1./255)(inputs)

    # Conv block 1
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2))(x)

    # Conv block 2
    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2))(x)

    # Conv block 3
    x = layers.Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2,2))(x)

    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    model = keras.Model(inputs=inputs, outputs=outputs, name="CNN_Classifier")
    return model

# %%
# Create the CNN model
cnn_model = create_cnn(input_shape=(64, 64, 3), num_classes=20)

# Train and evaluate
history_cnn, test_acc_cnn, test_loss_cnn, training_time_cnn = train_and_evaluate(
    cnn_model, "CNN_Classifier",
    x_train, y_train,
    x_val, y_val,
    x_test, y_test,
    epochs=20,
    batch_size=64,
    learning_rate=0.001
)

# Plot training history
plot_training_history(history_cnn)
# Out:
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - accuracy: 0.1109 - loss: 2.8665 - val_accuracy: 0.1840 - val_loss: 2.6351 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.1880 - loss: 2.6126 - val_accuracy: 0.2210 - val_loss: 2.4623 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2456 - loss: 2.4543 - val_accuracy: 0.2700 - val_loss: 2.3617 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2870 - loss: 2.3627 - val_accuracy: 0.2970 - val_loss: 2.2888 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.3207 - loss: 2.2484 - val_accuracy: 0.3300 - val_loss: 2.2335 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.3502 - loss: 2.1466 - val_accuracy: 0.3550 - val_loss: 2.1293 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3775 - loss: 2.0650 - val_accuracy: 0.3620 - val_loss: 2.1243 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.4028 - loss: 1.9575 - val_accuracy: 0.3590 - val_loss: 2.1503 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.4285 - loss: 1.8708 - val_accuracy: 0.3760 - val_loss: 2.0980 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.4417 - loss: 1.7883 - val_accuracy: 0.3780 - val_loss: 2.0936 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4676 - loss: 1.6903 - val_accuracy: 0.3930 - val_loss: 2.0888 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.4970 - loss: 1.5800 - val_accuracy: 0.3990 - val_loss: 2.1714 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.5140 - loss: 1.5330 - val_accuracy: 0.3880 - val_loss: 2.2468 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.5441 - loss: 1.3978 - val_accuracy: 0.4000 - val_loss: 2.3058 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.5736 - loss: 1.3238 - val_accuracy: 0.4200 - val_loss: 2.2183 - learning_rate: 1.0000e-04
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6062 - loss: 1.2197 - val_accuracy: 0.4080 - val_loss: 2.2313 - learning_rate: 1.0000e-04
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6260 - loss: 1.1680 - val_accuracy: 0.4160 - val_loss: 2.2453 - learning_rate: 1.0000e-04
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.6316 - loss: 1.1385 - val_accuracy: 0.4200 - val_loss: 2.2330 - learning_rate: 1.0000e-05
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6404 - loss: 1.1004 - val_accuracy: 0.4200 - val_loss: 2.2318 - learning_rate: 1.0000e-05
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6351 - loss: 1.1130 - val_accuracy: 0.4170 - val_loss: 2.2328 - learning_rate: 1.0000e-05
# CNN_Classifier - Test Accuracy: 0.4130, Test Loss: 2.1235
# CNN_Classifier - Training Time: 57.05 seconds

# %%
# ===================== Plot Comparison of Loss =====================
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history_vit.history['loss'], label='ViT Train')
plt.plot(history_vit.history['val_loss'], label='ViT Val')
plt.plot(history_fcfnn.history['loss'], label='FCFNN Train')
plt.plot(history_fcfnn.history['val_loss'], label='FCFNN Val')
plt.plot(history_cnn.history['loss'], label='CNN Train')
plt.plot(history_cnn.history['val_loss'], label='CNN Val')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# ===================== Plot Comparison of Accuracy =====================
plt.subplot(1,2,2)
plt.plot(history_vit.history['accuracy'], label='ViT Train')
plt.plot(history_vit.history['val_accuracy'], label='ViT Val')
plt.plot(history_fcfnn.history['accuracy'], label='FCFNN Train')
plt.plot(history_fcfnn.history['val_accuracy'], label='FCFNN Val')
plt.plot(history_cnn.history['accuracy'], label='CNN Train')
plt.plot(history_cnn.history['val_accuracy'], label='CNN Val')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# ===================== Print Test Accuracy, Loss, and Training Time =====================
print(f"ViT - Test Accuracy: {test_acc_vit:.4f}, Test Loss: {test_loss_vit:.4f}, Training Time: {training_time_vit:.2f} sec")
print(f"FCFNN - Test Accuracy: {test_acc_fcfnn:.4f}, Test Loss: {test_loss_fcfnn:.4f}, Training Time: {training_time_fcfnn:.2f} sec")
print(f"CNN - Test Accuracy: {test_acc_cnn:.4f}, Test Loss: {test_loss_cnn:.4f}, Training Time: {training_time_cnn:.2f} sec")
# Out:
# ViT - Test Accuracy: 0.2380, Test Loss: 2.4231, Training Time: 276.37 sec
# FCFNN - Test Accuracy: 0.2260, Test Loss: 2.5353, Training Time: 33.10 sec
# CNN - Test Accuracy: 0.4130, Test Loss: 2.1235, Training Time: 57.05 sec

# %% [markdown]
# ## Effect of Number of Head

# %%
import matplotlib.pyplot as plt

# Define the number of heads
head_options = [1, 2, 4, 8, 16]
results = []

for heads in head_options:
    print(f"\nTraining ViT with {heads} attention heads...")
    vit_model = create_vit_classifier(
        input_shape=(64, 64, 3),
        patch_size=4,
        projection_dim=64,
        num_heads=heads,
        transformer_layers=4,
        mlp_head_units=[128, 64],
        num_classes=20
    )

    history, test_acc, test_loss, training_time = train_and_evaluate(
        vit_model, f"ViT_{heads}_heads",
        x_train, y_train,
        x_val, y_val,
        x_test, y_test,
        epochs=20,
        batch_size=64,
        learning_rate=0.001
    )

    # Save results
    results.append({
        "heads": heads,
        "history": history,
        "test_acc": test_acc,
        "test_loss": test_loss,
        "training_time": training_time
    })

# ===================== Plot Accuracy and Loss vs Number of Heads =====================
accs = [r['test_acc'] for r in results]
losses = [r['test_loss'] for r in results]
times = [r['training_time'] for r in results]

plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.plot(head_options, accs, marker='o')
plt.title('Test Accuracy vs Number of Heads')
plt.xlabel('Number of Heads')
plt.ylabel('Test Accuracy')

plt.subplot(1,3,2)
plt.plot(head_options, losses, marker='o', color='red')
plt.title('Test Loss vs Number of Heads')
plt.xlabel('Number of Heads')
plt.ylabel('Test Loss')

plt.subplot(1,3,3)
plt.plot(head_options, times, marker='o', color='green')
plt.title('Training Time vs Number of Heads')
plt.xlabel('Number of Heads')
plt.ylabel('Training Time (sec)')

plt.tight_layout()
plt.show()
# Out:
# Training ViT with 1 attention heads...
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 50s 167ms/step - accuracy: 0.0614 - loss: 3.0699 - val_accuracy: 0.1530 - val_loss: 2.8337 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.1027 - loss: 2.8988 - val_accuracy: 0.1530 - val_loss: 2.7675 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 29ms/step - accuracy: 0.1319 - loss: 2.8154 - val_accuracy: 0.1930 - val_loss: 2.6541 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.1637 - loss: 2.7237 - val_accuracy: 0.2030 - val_loss: 2.6134 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.1803 - loss: 2.6659 - val_accuracy: 0.1990 - val_loss: 2.6083 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.1877 - loss: 2.6341 - val_accuracy: 0.2150 - val_loss: 2.5220 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2102 - loss: 2.5989 - val_accuracy: 0.2410 - val_loss: 2.4676 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2122 - loss: 2.5582 - val_accuracy: 0.2330 - val_loss: 2.4822 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.2189 - loss: 2.5331 - val_accuracy: 0.2400 - val_loss: 2.4849 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2313 - loss: 2.5138 - val_accuracy: 0.2350 - val_loss: 2.4512 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2459 - loss: 2.4746 - val_accuracy: 0.2300 - val_loss: 2.4739 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.2335 - loss: 2.4858 - val_accuracy: 0.2350 - val_loss: 2.4146 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2484 - loss: 2.4410 - val_accuracy: 0.2610 - val_loss: 2.3979 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.2554 - loss: 2.4314 - val_accuracy: 0.2710 - val_loss: 2.3874 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 29s 203ms/step - accuracy: 0.1858 - loss: 2.6599 - val_accuracy: 0.1950 - val_loss: 2.6431 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 29s 205ms/step - accuracy: 0.1873 - loss: 2.6492 - val_accuracy: 0.2110 - val_loss: 2.5738 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 207ms/step - accuracy: 0.2101 - loss: 2.5865 - val_accuracy: 0.1890 - val_loss: 2.5887 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.2060 - loss: 2.5859 - val_accuracy: 0.2160 - val_loss: 2.5296 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 206ms/step - accuracy: 0.2224 - loss: 2.5320 - val_accuracy: 0.2310 - val_loss: 2.4939 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 30s 210ms/step - accuracy: 0.2403 - loss: 2.4840 - val_accuracy: 0.2140 - val_loss: 2.4897 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 29s 206ms/step - accuracy: 0.2379 - loss: 2.4830 - val_accuracy: 0.2110 - val_loss: 2.4921 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.2396 - loss: 2.4754 - val_accuracy: 0.2070 - val_loss: 2.4915 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 210ms/step - accuracy: 0.2554 - loss: 2.4237 - val_accuracy: 0.2410 - val_loss: 2.4420 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.2539 - loss: 2.4042 - val_accuracy: 0.2370 - val_loss: 2.4411 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 30s 209ms/step - accuracy: 0.2648 - loss: 2.3783 - val_accuracy: 0.2540 - val_loss: 2.4282 - learning_rate: 0.0010
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 40s 204ms/step - accuracy: 0.2708 - loss: 2.3337 - val_accuracy: 0.2450 - val_loss: 2.4465 - learning_rate: 0.0010
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - accuracy: 0.2802 - loss: 2.3169 - val_accuracy: 0.2400 - val_loss: 2.4586 - learning_rate: 0.0010
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 29s 207ms/step - accuracy: 0.2914 - loss: 2.3005 - val_accuracy: 0.2380 - val_loss: 2.4350 - learning_rate: 0.0010
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.3044 - loss: 2.2472 - val_accuracy: 0.2560 - val_loss: 2.4365 - learning_rate: 1.0000e-04
# ViT_16_heads - Test Accuracy: 0.2610, Test Loss: 2.3814
# ViT_16_heads - Training Time: 792.93 seconds

# %% [markdown]
# ## Effect of Patch Size

# %%
import matplotlib.pyplot as plt

# Define different patch sizes to experiment with
patch_sizes = [2, 4, 8, 16]
results_patch = []

for patch in patch_sizes:
    print(f"\nTraining ViT with patch size {patch}x{patch}...")

    # Compute number of patches based on input image size 64x64
    num_patches = (64 // patch) ** 2

    vit_model = create_vit_classifier(
        input_shape=(64, 64, 3),
        patch_size=patch,
        num_patches=num_patches,
        projection_dim=64,
        num_heads=4,
        transformer_layers=4,
        mlp_head_units=[128, 64],
        num_classes=20
    )

    history, test_acc, test_loss, training_time = train_and_evaluate(
        vit_model, f"ViT_patch_{patch}",
        x_train, y_train,
        x_val, y_val,
        x_test, y_test,
        epochs=20,
        batch_size=64,
        learning_rate=0.001
    )

    results_patch.append({
        "patch_size": patch,
        "history": history,
        "test_acc": test_acc,
        "test_loss": test_loss,
        "training_time": training_time
    })

# ===================== Plot Test Accuracy, Loss, and Training Time =====================
accs = [r['test_acc'] for r in results_patch]
losses = [r['test_loss'] for r in results_patch]
times = [r['training_time'] for r in results_patch]

plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.plot(patch_sizes, accs, marker='o')
plt.title('Test Accuracy vs Patch Size')
plt.xlabel('Patch Size')
plt.ylabel('Test Accuracy')

plt.subplot(1,3,2)
plt.plot(patch_sizes, losses, marker='o', color='red')
plt.title('Test Loss vs Patch Size')
plt.xlabel('Patch Size')
plt.ylabel('Test Loss')

plt.subplot(1,3,3)
plt.plot(patch_sizes, times, marker='o', color='green')
plt.title('Training Time vs Patch Size')
plt.xlabel('Patch Size')
plt.ylabel('Training Time (sec)')

plt.tight_layout()
plt.show()
# Out:
# Training ViT with patch size 2x2...
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 147s 820ms/step - accuracy: 0.0634 - loss: 3.1401 - val_accuracy: 0.1200 - val_loss: 2.8975 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 98s 645ms/step - accuracy: 0.0935 - loss: 2.9389 - val_accuracy: 0.1370 - val_loss: 2.8119 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 140s 630ms/step - accuracy: 0.1194 - loss: 2.8757 - val_accuracy: 0.1760 - val_loss: 2.7108 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 144s 646ms/step - accuracy: 0.1434 - loss: 2.7861 - val_accuracy: 0.1910 - val_loss: 2.6672 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 89s 631ms/step - accuracy: 0.1672 - loss: 2.6829 - val_accuracy: 0.1850 - val_loss: 2.6384 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 144s 648ms/step - accuracy: 0.1871 - loss: 2.6345 - val_accuracy: 0.1820 - val_loss: 2.5915 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 142s 648ms/step - accuracy: 0.1970 - loss: 2.5740 - val_accuracy: 0.1890 - val_loss: 2.5710 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 142s 648ms/step - accuracy: 0.2131 - loss: 2.5344 - val_accuracy: 0.2020 - val_loss: 2.5546 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 142s 647ms/step - accuracy: 0.2296 - loss: 2.4688 - val_accuracy: 0.2130 - val_loss: 2.5325 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 142s 648ms/step - accuracy: 0.2458 - loss: 2.4386 - val_accuracy: 0.2140 - val_loss: 2.5290 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 89s 632ms/step - accuracy: 0.2479 - loss: 2.4197 - val_accuracy: 0.2030 - val_loss: 2.5541 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.1896 - loss: 2.6385 - val_accuracy: 0.1910 - val_loss: 2.5867 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.1977 - loss: 2.6164 - val_accuracy: 0.1980 - val_loss: 2.5697 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.2015 - loss: 2.6014 - val_accuracy: 0.2000 - val_loss: 2.5384 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.2029 - loss: 2.5801 - val_accuracy: 0.2020 - val_loss: 2.5519 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.2135 - loss: 2.5578 - val_accuracy: 0.2210 - val_loss: 2.5146 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2019 - loss: 2.5818 - val_accuracy: 0.2280 - val_loss: 2.4836 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2203 - loss: 2.5242 - val_accuracy: 0.2200 - val_loss: 2.4938 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.2162 - loss: 2.5134 - val_accuracy: 0.2370 - val_loss: 2.4525 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.2317 - loss: 2.4915 - val_accuracy: 0.2230 - val_loss: 2.4715 - learning_rate: 0.0010
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.2204 - loss: 2.5185 - val_accuracy: 0.2220 - val_loss: 2.4956 - learning_rate: 0.0010
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.2329 - loss: 2.4925 - val_accuracy: 0.2350 - val_loss: 2.4631 - learning_rate: 0.0010
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.2432 - loss: 2.4443 - val_accuracy: 0.2640 - val_loss: 2.3781 - learning_rate: 1.0000e-04
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.2540 - loss: 2.4057 - val_accuracy: 0.2590 - val_loss: 2.3723 - learning_rate: 1.0000e-04
# ViT_patch_8 - Test Accuracy: 0.2660, Test Loss: 2.3068
# ViT_patch_8 - Training Time: 103.09 seconds
#
# Training ViT with patch size 16x16...
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 48s 143ms/step - accuracy: 0.0558 - loss: 3.1074 - val_accuracy: 0.1270 - val_loss: 2.8764 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.0998 - loss: 2.9223 - val_accuracy: 0.1700 - val_loss: 2.7788 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1225 - loss: 2.8677 - val_accuracy: 0.1590 - val_loss: 2.7361 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.1449 - loss: 2.8048 - val_accuracy: 0.1720 - val_loss: 2.6849 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1580 - loss: 2.7458 - val_accuracy: 0.1830 - val_loss: 2.6816 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.1657 - loss: 2.7318 - val_accuracy: 0.1770 - val_loss: 2.6483 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1771 - loss: 2.6877 - val_accuracy: 0.1870 - val_loss: 2.6296 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.1817 - loss: 2.6710 - val_accuracy: 0.1950 - val_loss: 2.5894 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.1884 - loss: 2.6484 - val_accuracy: 0.1880 - val_loss: 2.5986 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1896 - loss: 2.6256 - val_accuracy: 0.2000 - val_loss: 2.5842 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.1895 - loss: 2.6207 - val_accuracy: 0.1970 - val_loss: 2.5663 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.1985 - loss: 2.5946 - val_accuracy: 0.1930 - val_loss: 2.5826 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.1970 - loss: 2.5966 - val_accuracy: 0.2050 - val_loss: 2.5438 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.2112 - loss: 2.5671 - val_accuracy: 0.2060 - val_loss: 2.5615 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.2033 - loss: 2.5818 - val_accuracy: 0.2210 - val_loss: 2.5092 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.2122 - loss: 2.5424 - val_accuracy: 0.2110 - val_loss: 2.5050 - learning_rate: 0.0010
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2154 - loss: 2.5440 - val_accuracy: 0.2120 - val_loss: 2.4905 - learning_rate: 0.0010
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2202 - loss: 2.5324 - val_accuracy: 0.2140 - val_loss: 2.4950 - learning_rate: 0.0010
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.2261 - loss: 2.5221 - val_accuracy: 0.2290 - val_loss: 2.4853 - learning_rate: 0.0010
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.2308 - loss: 2.5106 - val_accuracy: 0.1950 - val_loss: 2.5588 - learning_rate: 0.0010
# ViT_patch_16 - Test Accuracy: 0.2380, Test Loss: 2.4307
# ViT_patch_16 - Training Time: 88.61 seconds

# %% [markdown]
# ## Effect of Positional Embedding

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim, positional_embedding_type="learned", **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.positional_embedding_type = positional_embedding_type

        if positional_embedding_type == "learned":
            self.position_embedding = layers.Embedding(
                input_dim=num_patches, output_dim=projection_dim
            )
        elif positional_embedding_type == "sinusoidal":
            # Precompute sinusoidal embeddings
            self.position_embedding = self.get_sinusoidal_embeddings(num_patches, projection_dim)

    def get_sinusoidal_embeddings(self, num_patches, projection_dim):
        import numpy as np
        positions = np.arange(num_patches)[:, np.newaxis]
        dims = np.arange(projection_dim)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (dims//2)) / np.float32(projection_dim))
        angle_rads = positions * angle_rates
        # apply sin to even indices, cos to odd indices
        sines = np.sin(angle_rads[:, 0::2])
        cosines = np.cos(angle_rads[:, 1::2])
        embeddings = np.zeros((num_patches, projection_dim))
        embeddings[:, 0::2] = sines
        embeddings[:, 1::2] = cosines
        return tf.constant(embeddings, dtype=tf.float32)

    def call(self, patch):
        if self.positional_embedding_type == "learned":
            positions = tf.range(start=0, limit=self.num_patches, delta=1)
            encoded = self.projection(patch) + self.position_embedding(positions)
        elif self.positional_embedding_type == "sinusoidal":
            encoded = self.projection(patch) + self.position_embedding
        return encoded


# ===================== Compare Learned vs Sinusoidal =====================
positional_types = ["learned", "sinusoidal"]
results_pos = []

for p_type in positional_types:
    print(f"\nTraining ViT with {p_type} positional embedding...")

    vit_model = create_vit_classifier(
        input_shape=(64,64,3),
        patch_size=4,
        num_patches=(64//4)**2,
        projection_dim=64,
        num_heads=4,
        transformer_layers=4,
        mlp_head_units=[128,64],
        num_classes=20,
        positional_embedding_type=p_type
    )

    history, test_acc, test_loss, training_time = train_and_evaluate(
        vit_model, f"ViT_{p_type}_pos",
        x_train, y_train,
        x_val, y_val,
        x_test, y_test,
        epochs=20,
        batch_size=64,
        learning_rate=0.001
    )

    results_pos.append({
        "type": p_type,
        "history": history,
        "test_acc": test_acc,
        "test_loss": test_loss,
        "training_time": training_time
    })

# ===================== Plot Comparison =====================
accs = [r['test_acc'] for r in results_pos]
losses = [r['test_loss'] for r in results_pos]
times = [r['training_time'] for r in results_pos]

plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.bar(positional_types, accs, color=['blue','orange'])
plt.title('Test Accuracy vs Positional Embedding')
plt.ylabel('Test Accuracy')

plt.subplot(1,3,2)
plt.bar(positional_types, losses, color=['blue','orange'])
plt.title('Test Loss vs Positional Embedding')
plt.ylabel('Test Loss')

plt.subplot(1,3,3)
plt.bar(positional_types, times, color=['blue','orange'])
plt.title('Training Time vs Positional Embedding')
plt.ylabel('Training Time (sec)')

plt.tight_layout()
plt.show()

# ===================== Plot Training Curves =====================
plt.figure(figsize=(15,5))

for r in results_pos:
    history = r['history']
    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label=f"{r['type']} train")
    plt.plot(history.history['val_accuracy'], '--', label=f"{r['type']} val")
    plt.title("Training & Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label=f"{r['type']} train")
    plt.plot(history.history['val_loss'], '--', label=f"{r['type']} val")
    plt.title("Training & Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Training ViT with learned positional embedding...
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 55s 198ms/step - accuracy: 0.0613 - loss: 3.0868 - val_accuracy: 0.1200 - val_loss: 2.8924 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 66ms/step - accuracy: 0.1073 - loss: 2.9141 - val_accuracy: 0.1700 - val_loss: 2.7875 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.1307 - loss: 2.8367 - val_accuracy: 0.1830 - val_loss: 2.7217 - learning_rate: 0.0010
# Epoch 4/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - accuracy: 0.1483 - loss: 2.7569 - val_accuracy: 0.1730 - val_loss: 2.7171 - learning_rate: 0.0010
# Epoch 5/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.1719 - loss: 2.7088 - val_accuracy: 0.2110 - val_loss: 2.6287 - learning_rate: 0.0010
# Epoch 6/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.1913 - loss: 2.6505 - val_accuracy: 0.2000 - val_loss: 2.5823 - learning_rate: 0.0010
# Epoch 7/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - accuracy: 0.1905 - loss: 2.6180 - val_accuracy: 0.2030 - val_loss: 2.5403 - learning_rate: 0.0010
# Epoch 8/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2092 - loss: 2.5795 - val_accuracy: 0.2170 - val_loss: 2.5139 - learning_rate: 0.0010
# Epoch 9/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.2135 - loss: 2.5399 - val_accuracy: 0.2130 - val_loss: 2.5027 - learning_rate: 0.0010
# Epoch 10/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2176 - loss: 2.5333 - val_accuracy: 0.2120 - val_loss: 2.5200 - learning_rate: 0.0010
# Epoch 11/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2249 - loss: 2.5175 - val_accuracy: 0.2500 - val_loss: 2.4669 - learning_rate: 0.0010
# Epoch 12/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2395 - loss: 2.4630 - val_accuracy: 0.2220 - val_loss: 2.4802 - learning_rate: 0.0010
# Epoch 13/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - accuracy: 0.2461 - loss: 2.4572 - val_accuracy: 0.2370 - val_loss: 2.4402 - learning_rate: 0.0010
# Epoch 14/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2549 - loss: 2.4258 - val_accuracy: 0.2340 - val_loss: 2.4502 - learning_rate: 0.0010
# Epoch 15/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - accuracy: 0.2567 - loss: 2.4073 - val_accuracy: 0.2370 - val_loss: 2.4729 - learning_rate: 0.0010
# Epoch 16/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2652 - loss: 2.4022 - val_accuracy: 0.2560 - val_loss: 2.3978 - learning_rate: 0.0010
# Epoch 17/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - accuracy: 0.2841 - loss: 2.3523 - val_accuracy: 0.2740 - val_loss: 2.3867 - learning_rate: 0.0010
# Epoch 18/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2897 - loss: 2.3205 - val_accuracy: 0.2840 - val_loss: 2.3710 - learning_rate: 0.0010
# Epoch 19/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2973 - loss: 2.3140 - val_accuracy: 0.2840 - val_loss: 2.3503 - learning_rate: 0.0010
# Epoch 20/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 9s 64ms/step - accuracy: 0.2986 - loss: 2.3161 - val_accuracy: 0.2860 - val_loss: 2.3503 - learning_rate: 0.0010
# ViT_learned_pos - Test Accuracy: 0.2960, Test Loss: 2.3212
# ViT_learned_pos - Training Time: 241.74 seconds
#
# Training ViT with sinusoidal positional embedding...
# Epoch 1/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 57s 203ms/step - accuracy: 0.0599 - loss: 3.0873 - val_accuracy: 0.1380 - val_loss: 2.8857 - learning_rate: 0.0010
# Epoch 2/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 46s 63ms/step - accuracy: 0.0945 - loss: 2.9294 - val_accuracy: 0.1500 - val_loss: 2.8307 - learning_rate: 0.0010
# Epoch 3/20
# 141/141 ━━━━━━━━━━━━━━━━━━━━